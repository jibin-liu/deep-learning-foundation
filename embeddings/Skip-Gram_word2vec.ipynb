# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:09, 3.14MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]   # list of whole vocab words in the form of int

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

def subsampling(words, t):
    """ subsampling the input words by given threshold t """
    words_counter = Counter(words)
    vob_len = len(words)
    freq = {word: counts / vob_len for word, counts in words_counter.items()}
    prob = {word: 1 - np.sqrt(t / freq[word]) for word in freq}  # prob to drop
    
    # the way to sample the data based on probablity is that:
    #   a. generate a random number using random.random;
    #   b. compare the prob with random number. If the prob to drop is less than the random number, keep it
    #   c. since random.random is sampling from a uniform-distribution, it works like a probablity sampler
    # e.g., if prob[word] is 0.7. Then random.random will have 70% of the chance to generate a number less
    #       than 0.7, and 30% to be greater than 0.7. This keeps the actual prob to drop the word at 70%
    subsample = [word for word in words if prob[word] < random.random()]
    return subsample

train_words = subsampling(int_words, 0.0001)# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
a = [1, 2, 3, 4]
a[1:10]
# Out:
# [2, 3, 4]

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # pick a random number R in range [1, C]
    r = random.randint(1, 5)
    
    min_idx = 0 if (idx - r) < 0 else (idx - r)
    max_idx = idx + r + 1
    
    # use set to remove duplicate
    neighbors = set([*words[min_idx:idx], *words[idx + 1: max_idx]])
    
    return list(neighbors)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],
                                                stddev= 1.0 / np.sqrt(n_vocab)))  # create softmax weight matrix here
    # why the shape of softmax_w is [n_vocab, n_embedding], but not [n_embedding, n_vocab]?
    
    softmax_b = tf.Variable(tf.zeros(n_vocab))  # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      inputs=embed,
                                      labels=labels,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.1874 0.3897 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.1730 0.3898 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.9805 0.3871 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7743 0.3865 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4768 0.3854 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2536 0.3842 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2048 0.3855 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0439 0.3847 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9900 0.3824 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.9549 0.3824 sec/batch
# Nearest to one: locals, conservative, did, distance, greeks, s, heterosexual, chewed,
# Nearest to where: correspondent, pattern, gone, exercised, want, ambrogio, burns, avoided,
# Nearest to two: per, box, hast, portugal, secret, humanity, nietzsche, noticeable,
# Nearest to will: computer, balance, alternate, pita, scene, drunk, happened, warning,
# Nearest to used: versions, arlington, production, things, seen, recessive, appeals, jacobites,
# Nearest to people: incorrectly, hod, martin, depicted, victory, ordered, midi, specially,
# Nearest to new: furthermore, extended, speaker, excessive, participating, space, content, rica,
# Nearest to over: clouds, miles, deployed, roles, theory, rabin, entirely, discovered,
# Nearest to proposed: intercourse, li, horseman, treated, underworld, transitional, invaded, infrastructure,
# Nearest to grand: hugh, australian, mathematicians, forl, widely, america, punctuation, throttle,
# Nearest to orthodox: noteworthy, completion, abduction, majority, leader, blow, hacked, minneapolis,
# Nearest to rise: angelico, beardsley, pedestrian, wholly, scotland, rising, modified, certificates,
# Nearest to defense: editions, hands, adolphe, commencement, development, age, involved, funds,
# Nearest to accepted: rarities, reilly, centered, resident, swamp, dn, source, theseus,
# Nearest to arts: february, exported, lesser, until, finding, upper, mention, ivor,
# Nearest to magazine: asking, navies, necessary, mtv, abstinence, asia, namely, take,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9220 0.3830 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.8875 0.3781 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.8700 0.3764 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.8841 0.3760 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8176 0.3786 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.7714 0.3799 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7594 0.3789 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7610 0.3749 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7427 0.3711 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7093 0.3715 sec/batch
# Nearest to one: conservative, locals, heterosexual, apec, aram, chewed, monotonous, clemency,
# Nearest to where: correspondent, pattern, ambrogio, turnout, dedicate, kuwaiti, want, exercised,
# Nearest to two: per, hast, eaglet, nietzsche, bulldogs, box, aldrin, answering,
# Nearest to will: pita, balance, alternate, happened, computer, incorrect, picard, scene,
# Nearest to used: versions, arlington, production, things, recessive, seen, parallelism, overlaps,
# Nearest to people: hod, incorrectly, economies, restores, imperfections, martin, midi, fabaceae,
# Nearest to new: rica, participating, excessive, furthermore, xp, bombay, precluded, gifford,
# Nearest to over: clouds, deployed, miles, computes, rabin, charm, revolver, solano,
# Nearest to proposed: intercourse, underworld, horseman, emu, transitional, li, fourteenth, moons,
# Nearest to grand: hugh, australian, forl, throttle, mathematicians, romania, calf, punctuation,
# Nearest to orthodox: noteworthy, abduction, completion, hacked, minneapolis, packaged, majority, snap,
# Nearest to rise: pedestrian, angelico, manage, beardsley, rising, certificates, onslaught, loop,
# Nearest to defense: commencement, adolphe, workprint, hands, leicestershire, editions, funds, loi,
# Nearest to accepted: rarities, bulgogi, panama, opentype, centered, elrond, theseus, dn,
# Nearest to arts: exported, february, lesser, ivor, sovereign, anderson, qa, luddites,
# Nearest to magazine: navies, brinton, asking, mtv, surplus, abstinence, plotted, namely,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6014 0.3767 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6941 0.3706 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6347 0.3703 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6591 0.3700 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6136 0.3675 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7006 0.3700 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6425 0.3696 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6172 0.3687 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6084 0.3680 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5904 0.3684 sec/batch
# Nearest to one: apec, aylwin, monotonous, bfi, heterosexual, aram, hugo, locals,
# Nearest to where: correspondent, ambrogio, innately, pattern, dedicate, computes, kuwaiti, exercised,
# Nearest to two: per, eaglet, bulldogs, aldrin, hast, answering, nietzsche, downed,
# Nearest to will: pita, happened, balance, spoon, incorrect, alternate, drunk, magistracies,
# Nearest to used: versions, arlington, production, recessive, uses, parallelism, relate, westmacott,
# Nearest to people: hod, economies, imperfections, midi, fabaceae, restores, incorrectly, chang,
# Nearest to new: rica, participating, york, precluded, speleology, gifford, excessive, miasto,
# Nearest to over: clouds, charm, revolver, dominatrixes, automaton, solano, pentagram, computes,
# Nearest to proposed: intercourse, emu, underworld, horseman, header, transitional, fourteenth, quench,
# Nearest to grand: hugh, throttle, forl, romania, australian, holiday, punctuation, lodgings,
# Nearest to orthodox: abduction, noteworthy, xinjiang, majority, princes, packaged, isin, muslims,
# Nearest to rise: pedestrian, angelico, certificates, onslaught, beardsley, manage, cheese, rising,
# Nearest to defense: commencement, workprint, adolphe, leicestershire, hands, credible, loi, parliamentarians,
# Nearest to accepted: rarities, bulgogi, centered, opentype, elrond, bamberg, bungee, reactionary,
# Nearest to arts: exported, february, qa, ivor, specious, lesser, nathaniel, ignacio,
# Nearest to magazine: brinton, navies, asking, mtv, surplus, tristan, plotted, fest,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6045 0.3738 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5929 0.3701 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5824 0.3683 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5835 0.3718 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5835 0.3676 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5671 0.3671 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5009 0.3674 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4862 0.3656 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5369 0.3684 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5212 0.3657 sec/batch
# Nearest to one: aylwin, bfi, monotonous, apec, hugo, heterosexual, cornelis, aram,
# Nearest to where: correspondent, ambrogio, computes, pattern, dedicate, harmless, kuwaiti, bermudez,
# Nearest to two: per, synergies, aldrin, eaglet, bulldogs, novices, subliminal, downed,
# Nearest to will: pita, happened, spoon, drunk, balance, rambling, incorrect, phosphine,
# Nearest to used: versions, production, arlington, recessive, uses, parallelism, carpenters, westmacott,
# Nearest to people: economies, hod, treacherous, wojciech, fabaceae, boasted, leah, spread,
# Nearest to new: rica, york, speleology, participating, mei, precluded, bankhead, gerard,
# Nearest to over: clouds, dominatrixes, pentagram, studi, solano, rabin, acura, revolver,
# Nearest to proposed: intercourse, emu, underworld, horseman, fourteenth, li, transitional, lecturer,
# Nearest to grand: hugh, throttle, lodgings, forl, australian, tempus, bournemouth, holiday,
# Nearest to orthodox: abduction, majority, princes, muslims, roman, noteworthy, xinjiang, isin,
# Nearest to rise: pedestrian, angelico, onslaught, certificates, cheese, manage, beardsley, blackbird,
# Nearest to defense: workprint, commencement, adolphe, leicestershire, loi, hands, kenilworth, credible,
# Nearest to accepted: rarities, bulgogi, opentype, centered, elrond, bamberg, reactionary, dn,
# Nearest to arts: exported, covenanters, specious, qa, february, ignacio, salman, defy,
# Nearest to magazine: brinton, navies, mtv, tristan, historicity, dustin, guardia, asking,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5544 0.3715 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4860 0.3680 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4833 0.3675 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5287 0.3688 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4224 0.3641 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5320 0.3670 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.4702 0.3651 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.3976 0.3663 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.4953 0.3664 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.4918 0.3640 sec/batch
# Nearest to one: monotonous, aylwin, bfi, apec, forefather, hugo, aram, heterosexual,
# Nearest to where: correspondent, ambrogio, computes, dedicate, innately, bermudez, harmless, pattern,
# Nearest to two: per, synergies, aldrin, eaglet, bulldogs, outsource, subliminal, novices,
# Nearest to will: happened, pita, spoon, drunk, disproven, incorrect, rambling, phosphine,
# Nearest to used: versions, recessive, arlington, production, uses, carpenters, parallelism, jacobites,
# Nearest to people: treacherous, hod, economies, wojciech, fabaceae, boasted, blimp, magister,
# Nearest to new: rica, york, speleology, mei, participating, precluded, gifford, bankhead,
# Nearest to over: clouds, pentagram, dominatrixes, studi, dwt, miles, rabin, acura,
# Nearest to proposed: intercourse, underworld, emu, horseman, quench, lecturer, gorgosaurus, li,
# Nearest to grand: hugh, throttle, lodgings, forl, australian, bournemouth, tempus, holiday,
# Nearest to orthodox: muslims, abduction, princes, noteworthy, xinjiang, isin, majority, allah,
# Nearest to rise: angelico, pedestrian, onslaught, cheese, beardsley, blackbird, certificates, manage,
# Nearest to defense: workprint, commencement, leicestershire, adolphe, loi, hands, kenilworth, doraemon,
# Nearest to accepted: rarities, bulgogi, elrond, centered, opentype, bungee, bamberg, dn,
# Nearest to arts: exported, covenanters, specious, ignacio, qa, lesser, blogger, catapults,
# Nearest to magazine: brinton, navies, mtv, tristan, guardia, historicity, dustin, environmentalist,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.4813 0.3736 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.4763 0.3652 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.4037 0.3649 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.4913 0.3667 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.4292 0.3669 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.4876 0.3662 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.4349 0.3672 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.4335 0.3653 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.3371 0.3683 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.4065 0.3678 sec/batch
# Nearest to one: aylwin, bfi, apec, forefather, monotonous, cornelis, wedded, hugo,
# Nearest to where: correspondent, ambrogio, computes, innately, pattern, dedicate, bermudez, rigour,
# Nearest to two: per, synergies, eaglet, aldrin, outsource, bulldogs, subliminal, novices,
# Nearest to will: happened, pita, drunk, spoon, disproven, incorrect, rambling, lungs,
# Nearest to used: versions, recessive, production, uses, arlington, carpenters, librorum, hominin,
# Nearest to people: hod, treacherous, economies, wojciech, fabaceae, downplay, tessa, impiety,
# Nearest to new: york, rica, speleology, participating, mei, bankhead, midianites, miasto,
# Nearest to over: clouds, studi, dominatrixes, pentagram, acura, cyrenaica, rabin, dwt,
# Nearest to proposed: intercourse, emu, underworld, horseman, gorgosaurus, quench, clav, canes,
# Nearest to grand: lodgings, hugh, throttle, bournemouth, forl, tempus, australian, halpin,
# Nearest to orthodox: muslims, abduction, isin, allah, noteworthy, xinjiang, princes, edsel,
# Nearest to rise: angelico, pedestrian, onslaught, beardsley, cheese, blackbird, manage, rising,
# Nearest to defense: workprint, commencement, loi, security, adolphe, doraemon, leicestershire, kenilworth,
# Nearest to accepted: rarities, opentype, elrond, bulgogi, bungee, reactionary, centered, bamberg,
# Nearest to arts: exported, covenanters, blogger, qa, ignacio, specious, catapults, plantations,
# Nearest to magazine: brinton, mtv, navies, dustin, guardia, environmentalist, tristan, asking,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.4086 0.3684 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.3736 0.3639 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.4374 0.3645 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.2910 0.3645 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.3069 0.3638 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.4107 0.3638 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.4378 0.3660 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.4132 0.3660 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.4978 0.3661 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.4336 0.3640 sec/batch
# Nearest to one: aylwin, bfi, forefather, apec, monotonous, freas, cornelis, jordanians,
# Nearest to where: correspondent, ambrogio, computes, bermudez, innately, osprey, infanticide, stuffed,
# Nearest to two: per, synergies, sara, aldrin, outsource, eaglet, bulldogs, novices,
# Nearest to will: drunk, pita, happened, spoon, disproven, rambling, forrester, incorrect,
# Nearest to used: versions, recessive, uses, arlington, carpenters, production, librorum, menahem,
# Nearest to people: hod, treacherous, fabaceae, downplay, economies, wojciech, tessa, impiety,
# Nearest to new: york, rica, speleology, bankhead, miasto, participating, mei, dubois,
# Nearest to over: clouds, dominatrixes, studi, acura, pentagram, superfund, cyrenaica, computes,
# Nearest to proposed: intercourse, emu, underworld, horseman, gorgosaurus, canes, clav, positions,
# Nearest to grand: hugh, lodgings, throttle, bournemouth, forl, tempus, dwyer, bretons,
# Nearest to orthodox: muslims, abduction, noteworthy, edsel, princes, isin, irenaeus, allah,
# Nearest to rise: onslaught, angelico, pedestrian, rising, cheese, beardsley, blackbird, perk,
# Nearest to defense: workprint, commencement, loi, kenilworth, leicestershire, doraemon, adolphe, security,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, bungee, wheelbase, bamberg, dn,
# Nearest to arts: exported, blogger, qa, covenanters, specious, ignacio, catapults, plantations,
# Nearest to magazine: brinton, navies, mtv, environmentalist, tristan, dustin, asking, marvelman,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.2596 0.3698 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.4243 0.3623 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.4051 0.3614 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.3964 0.3636 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.4336 0.3645 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.3605 0.3646 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.1538 0.3625 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.3839 0.3629 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.2942 0.3623 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.3749 0.3641 sec/batch
# Nearest to one: aylwin, bfi, buonarroti, apec, cornelis, monotonous, forefather, freas,
# Nearest to where: correspondent, ambrogio, bermudez, innately, computes, rigour, osprey, dedicate,
# Nearest to two: per, eaglet, outsource, sara, aldrin, bulldogs, togethers, subliminal,
# Nearest to will: spoon, drunk, happened, pita, rambling, disproven, inline, forrester,
# Nearest to used: versions, uses, recessive, production, arlington, carpenters, seen, menahem,
# Nearest to people: hod, treacherous, downplay, fabaceae, impiety, wojciech, economies, boasted,
# Nearest to new: york, rica, speleology, bankhead, miasto, participating, gloss, establishments,
# Nearest to over: dominatrixes, studi, clouds, pentagram, acura, superfund, cyrenaica, dwt,
# Nearest to proposed: intercourse, emu, horseman, clav, underworld, gorgosaurus, synthesisers, positions,
# Nearest to grand: lodgings, hugh, throttle, bournemouth, forl, agglomerations, tempus, dwyer,
# Nearest to orthodox: muslims, abduction, noteworthy, princes, edsel, irenaeus, isin, allah,
# Nearest to rise: angelico, onslaught, pedestrian, rising, cheese, beardsley, perk, blackbird,
# Nearest to defense: workprint, commencement, leicestershire, doraemon, loi, parliamentarians, kenilworth, adolphe,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, bungee, anicetus, wheelbase, reactionary,
# Nearest to arts: exported, blogger, art, qa, covenanters, luddites, catapults, plantations,
# Nearest to magazine: brinton, mtv, navies, tristan, marvelman, asking, dustin, environmentalist,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.3457 0.3674 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.3520 0.3634 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.3781 0.3627 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4198 0.0442 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.2686 0.3654 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2944 0.3616 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2317 0.3638 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2622 0.3637 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2429 0.3619 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2446 0.3619 sec/batch
# Nearest to one: aylwin, apec, bfi, buonarroti, cornelis, aram, freas, forefather,
# Nearest to where: correspondent, ambrogio, bermudez, dedicate, innately, rigour, osprey, harmless,
# Nearest to two: per, sara, eaglet, nonresident, downed, outsource, synergies, bulldogs,
# Nearest to will: drunk, spoon, pita, happened, rambling, forrester, disproven, magistracies,
# Nearest to used: versions, uses, recessive, menahem, arlington, production, carpenters, seen,
# Nearest to people: hod, treacherous, downplay, fabaceae, boasted, tessa, wojciech, impiety,
# Nearest to new: york, rica, speleology, miasto, bankhead, participating, ytterbium, mei,
# Nearest to over: studi, dominatrixes, clouds, pentagram, acura, superfund, cyrenaica, revolver,
# Nearest to proposed: intercourse, emu, underworld, clav, gorgosaurus, horseman, synthesisers, reaffirming,
# Nearest to grand: lodgings, hugh, throttle, bournemouth, forl, tempus, dwyer, agglomerations,
# Nearest to orthodox: muslims, noteworthy, abduction, edsel, princes, allah, soter, stab,
# Nearest to rise: onslaught, angelico, pedestrian, rising, cheese, blackbird, perk, kreutzmann,
# Nearest to defense: commencement, leicestershire, workprint, doraemon, loi, parliamentarians, erfurt, adolphe,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, wheelbase, anicetus, reactionary, bungee,
# Nearest to arts: exported, blogger, art, qa, luddites, covenanters, catapults, plantations,
# Nearest to magazine: brinton, tristan, mtv, navies, marvelman, dustin, environmentalist, guardia,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2633 0.3670 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2358 0.3630 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.2741 0.3647 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.2388 0.3603 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.2363 0.3611 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.1258 0.3616 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.2871 0.3615 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.3246 0.3629 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.2855 0.3623 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.3023 0.3607 sec/batch
# Nearest to one: aylwin, apec, bfi, buonarroti, freas, forefather, kwh, vanished,
# Nearest to where: ambrogio, correspondent, bermudez, innately, rigour, osprey, harmless, dedicate,
# Nearest to two: per, sara, outsource, bulldogs, synergies, eaglet, deorum, downed,
# Nearest to will: drunk, pita, spoon, happened, disproven, magistracies, rambling, forrester,
# Nearest to used: versions, uses, recessive, carpenters, menahem, arlington, seen, librorum,
# Nearest to people: hod, downplay, treacherous, fabaceae, boasted, wojciech, tessa, economies,
# Nearest to new: york, rica, speleology, participating, ytterbium, bankhead, slashes, miasto,
# Nearest to over: dominatrixes, studi, clouds, acura, pentagram, superfund, cyrenaica, dwt,
# Nearest to proposed: intercourse, emu, underworld, clav, gorgosaurus, horseman, synthesisers, theories,
# Nearest to grand: lodgings, throttle, hugh, dwyer, bournemouth, tempus, conversing, forl,
# Nearest to orthodox: muslims, noteworthy, abduction, allah, edsel, soter, princes, stab,
# Nearest to rise: onslaught, rising, angelico, pedestrian, blackbird, cheese, perk, kreutzmann,
# Nearest to defense: commencement, leicestershire, workprint, doraemon, loi, parliamentarians, erfurt, rockne,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, bungee, wheelbase, adhere,
# Nearest to arts: exported, blogger, art, qa, covenanters, luddites, catapults, ignacio,
# Nearest to magazine: brinton, marvelman, mtv, tristan, navies, dustin, guardia, achille,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.2705 0.3657 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.2706 0.3620 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.2253 0.3605 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 4.1766 0.3590 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.0557 0.3608 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.2226 0.3596 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.2104 0.3601 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.2195 0.3612 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.2077 0.3624 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.2480 0.3640 sec/batch
# Nearest to one: aylwin, apec, bfi, buonarroti, kwh, freas, forefather, cavalryman,
# Nearest to where: correspondent, ambrogio, bermudez, rigour, leftrightarrow, computes, innately, harmless,
# Nearest to two: per, bulldogs, associates, eaglet, deorum, synergies, sara, downed,
# Nearest to will: drunk, pita, spoon, happened, passively, rambling, magistracies, disproven,
# Nearest to used: versions, uses, recessive, carpenters, menahem, seen, correspondents, hominin,
# Nearest to people: hod, downplay, treacherous, fabaceae, economies, tessa, lichens, boasted,
# Nearest to new: york, speleology, rica, ytterbium, miasto, slashes, bankhead, dubois,
# Nearest to over: dominatrixes, pentagram, clouds, acura, studi, superfund, computes, cyrenaica,
# Nearest to proposed: intercourse, emu, underworld, clav, gorgosaurus, synthesisers, theories, horseman,
# Nearest to grand: lodgings, hugh, throttle, dwyer, tempus, bournemouth, forl, conversing,
# Nearest to orthodox: muslims, noteworthy, abduction, isin, edsel, princes, irenaeus, allah,
# Nearest to rise: rising, onslaught, cheese, pedestrian, perk, angelico, blackbird, kreutzmann,
# Nearest to defense: commencement, leicestershire, doraemon, workprint, parliamentarians, erfurt, loi, rockne,
# Nearest to accepted: rarities, bulgogi, opentype, elrond, anicetus, bungee, wheelbase, adhere,
# Nearest to arts: exported, blogger, art, covenanters, qa, ignacio, luddites, parkland,
# Nearest to magazine: brinton, marvelman, mtv, tristan, navies, environmentalist, dustin, guardia,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.2485 0.3686 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 4.2309 0.3608 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 4.1896 0.3609 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.2744 0.3631 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 4.1510 0.3634 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.2087 0.3611 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.2205 0.3623 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.2610 0.3619 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.2628 0.3651 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.2194 0.3615 sec/batch
# Nearest to one: aylwin, buonarroti, bfi, apec, kwh, freas, cavalryman, nicky,
# Nearest to where: correspondent, ambrogio, bermudez, leftrightarrow, rigour, harmless, computes, calculating,
# Nearest to two: per, bulldogs, deorum, synergies, sara, downed, eaglet, outsource,
# Nearest to will: spoon, drunk, pita, passively, happened, balance, disproven, forrester,
# Nearest to used: versions, uses, carpenters, recessive, seen, menahem, correspondents, hominin,
# Nearest to people: downplay, hod, fabaceae, treacherous, economies, tessa, divus, boasted,
# Nearest to new: york, speleology, rica, bankhead, miasto, gloss, ytterbium, participating,
# Nearest to over: dominatrixes, acura, pentagram, clouds, studi, revolvers, superfund, computes,
# Nearest to proposed: intercourse, emu, theories, clav, synthesisers, gorgosaurus, underworld, furlong,
# Nearest to grand: lodgings, hugh, throttle, bournemouth, tempus, forl, conversing, dwyer,
# Nearest to orthodox: noteworthy, muslims, soter, stab, irenaeus, edsel, abduction, isin,
# Nearest to rise: onslaught, rising, perk, blackbird, cheese, angelico, pedestrian, kreutzmann,
# Nearest to defense: doraemon, commencement, leicestershire, loi, parliamentarians, workprint, defence, erfurt,
# Nearest to accepted: rarities, bulgogi, opentype, elrond, anicetus, bungee, wheelbase, embed,
# Nearest to arts: exported, art, blogger, qa, covenanters, luddites, unger, parkland,
# Nearest to magazine: brinton, marvelman, mtv, tristan, navies, guardia, environmentalist, dustin,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.1754 0.3686 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.1539 0.3626 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.2437 0.3626 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.2107 0.3606 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.2712 0.3642 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.1402 0.3622 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.1836 0.3643 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.2338 0.3641 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.1480 0.3609 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.2305 0.3655 sec/batch
# Nearest to one: aylwin, buonarroti, apec, kwh, freas, bfi, forefather, hugo,
# Nearest to where: correspondent, ambrogio, bermudez, leftrightarrow, rigour, computes, harmless, tenedos,
# Nearest to two: per, synergies, deorum, outsource, bulldogs, associates, nonresident, berthollet,
# Nearest to will: spoon, drunk, pita, happened, passively, forrester, balance, magistracies,
# Nearest to used: uses, versions, menahem, correspondents, recessive, seen, carpenters, hominin,
# Nearest to people: downplay, hod, treacherous, fabaceae, economies, divus, tessa, impiety,
# Nearest to new: york, speleology, rica, gloss, slashes, ytterbium, bankhead, miasto,
# Nearest to over: dominatrixes, pentagram, studi, acura, clouds, computes, antipsychotic, cyrenaica,
# Nearest to proposed: emu, intercourse, theories, underworld, clav, gorgosaurus, synthesisers, reaffirming,
# Nearest to grand: lodgings, throttle, bournemouth, hugh, tempus, conversing, forl, bretons,
# Nearest to orthodox: noteworthy, muslims, irenaeus, soter, oriental, eretria, abduction, stab,
# Nearest to rise: rising, onslaught, perk, blackbird, angelico, kreutzmann, pedestrian, cheese,
# Nearest to defense: doraemon, commencement, leicestershire, loi, parliamentarians, defence, workprint, erfurt,
# Nearest to accepted: rarities, bulgogi, elrond, anicetus, opentype, adhere, bungee, reactionary,
# Nearest to arts: exported, art, blogger, qa, lesser, covenanters, baleen, unger,
# Nearest to magazine: brinton, marvelman, tristan, mtv, environmentalist, dustin, navies, abiotic,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.1957 0.3687 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.1050 0.3622 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.2450 0.3642 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.2103 0.3648 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.2560 0.3636 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.2205 0.3642 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.1545 0.3618 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.2380 0.3630 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.2084 0.3618 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.2536 0.3615 sec/batch
# Nearest to one: aylwin, kwh, apec, buonarroti, freas, estimate, lzw, forefather,
# Nearest to where: correspondent, ambrogio, leftrightarrow, bermudez, harmless, rigour, innately, computes,
# Nearest to two: per, synergies, deorum, christoffel, outsource, sara, nonresident, berthollet,
# Nearest to will: spoon, pita, drunk, happened, passively, disproven, forrester, magistracies,
# Nearest to used: uses, versions, menahem, seen, correspondents, recessive, carpenters, hominin,
# Nearest to people: downplay, treacherous, hod, fabaceae, economies, divus, wojciech, boasted,
# Nearest to new: york, speleology, rica, gloss, bankhead, slashes, rajput, ytterbium,
# Nearest to over: dominatrixes, studi, pentagram, clouds, antipsychotic, computes, cyrenaica, acura,
# Nearest to proposed: emu, intercourse, clav, theories, underworld, gorgosaurus, synthesisers, leibniz,
# Nearest to grand: lodgings, throttle, bournemouth, hugh, tempus, conversing, forl, bretons,
# Nearest to orthodox: noteworthy, muslims, eretria, stab, irenaeus, isin, soter, oriental,
# Nearest to rise: rising, onslaught, perk, blackbird, angelico, cheese, pedestrian, kreutzmann,
# Nearest to defense: doraemon, commencement, loi, parliamentarians, leicestershire, defence, erfurt, workprint,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, reactionary, plankalk,
# Nearest to arts: art, exported, blogger, qa, unger, lesser, covenanters, conveyor,
# Nearest to magazine: brinton, marvelman, tristan, dustin, navies, mtv, slade, regionalism,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.2160 0.3676 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.2160 0.3640 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.0987 0.3621 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.1652 0.3638 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.1964 0.3622 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.1632 0.3612 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.2100 0.3616 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0668 0.3624 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.1215 0.3615 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.2192 0.3625 sec/batch
# Nearest to one: aylwin, buonarroti, freas, kwh, mayer, nicky, forefather, doon,
# Nearest to where: correspondent, ambrogio, bermudez, leftrightarrow, when, osprey, dedicate, tenedos,
# Nearest to two: deorum, sara, bertram, per, synergies, four, nonresident, berthollet,
# Nearest to will: spoon, drunk, pita, happened, passively, forrester, einhard, disproven,
# Nearest to used: uses, versions, menahem, seen, recessive, correspondents, carpenters, arlington,
# Nearest to people: downplay, hod, treacherous, fabaceae, autodidacts, tessa, economies, divus,
# Nearest to new: york, speleology, rica, rajput, burr, bankhead, dubois, slashes,
# Nearest to over: dominatrixes, studi, cyrenaica, clouds, pentagram, acura, gumby, antipsychotic,
# Nearest to proposed: emu, intercourse, clav, gorgosaurus, underworld, synthesisers, theories, leibniz,
# Nearest to grand: lodgings, bournemouth, hugh, throttle, forl, tempus, agglomerations, bretons,
# Nearest to orthodox: noteworthy, irenaeus, eretria, stab, ethiopic, packaged, soter, abduction,
# Nearest to rise: rising, onslaught, perk, blackbird, angelico, pedestrian, cheese, kreutzmann,
# Nearest to defense: loi, parliamentarians, doraemon, commencement, defence, leicestershire, kenilworth, workprint,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, reactionary, resident,
# Nearest to arts: exported, art, qa, blogger, unger, lesser, luddites, baleen,
# Nearest to magazine: brinton, marvelman, tristan, slade, dustin, navies, environmentalist, regionalism,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.2200 0.3666 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.2647 0.3629 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.2813 0.3649 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.2341 0.3610 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.0527 0.3618 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.2122 0.3612 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.1544 0.3605 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.2008 0.3613 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.2112 0.3610 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.1196 0.3641 sec/batch
# Nearest to one: kwh, aylwin, freas, apec, desks, nyc, estimate, lzw,
# Nearest to where: correspondent, ambrogio, leftrightarrow, bermudez, harmless, when, innately, osprey,
# Nearest to two: deorum, per, outsource, christoffel, synergies, sara, eaglet, nonresident,
# Nearest to will: spoon, pita, drunk, passively, happened, forrester, disproven, magistracies,
# Nearest to used: uses, versions, seen, menahem, carpenters, correspondents, recessive, arlington,
# Nearest to people: downplay, hod, treacherous, fabaceae, economies, autodidacts, tessa, divus,
# Nearest to new: york, speleology, rica, dubois, ytterbium, slashes, burr, bombay,
# Nearest to over: dominatrixes, clouds, studi, acura, antipsychotic, cyrenaica, gumby, pentagram,
# Nearest to proposed: emu, intercourse, clav, synthesisers, gorgosaurus, underworld, theories, reaffirming,
# Nearest to grand: lodgings, bournemouth, hugh, throttle, tempus, agglomerations, forl, halpin,
# Nearest to orthodox: noteworthy, stab, eretria, irenaeus, abduction, packaged, ethiopic, soter,
# Nearest to rise: rising, onslaught, perk, angelico, blackbird, pedestrian, cheese, kreutzmann,
# Nearest to defense: loi, parliamentarians, doraemon, defence, commencement, leicestershire, kenilworth, erfurt,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, plankalk, resident,
# Nearest to arts: art, qa, blogger, exported, unger, lesser, covenanters, luddites,
# Nearest to magazine: brinton, marvelman, tristan, slade, dustin, package, navies, environmentalist,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 3.9406 0.3700 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.2299 0.3630 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.1136 0.3606 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.1835 0.3624 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.1670 0.3616 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.1721 0.3613 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.1957 0.3627 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 4.2340 0.0871 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 4.1391 0.3620 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 4.1531 0.3633 sec/batch
# Nearest to one: kwh, aylwin, freas, semen, buonarroti, lzw, nyc, vanished,
# Nearest to where: correspondent, ambrogio, leftrightarrow, bermudez, when, osprey, harmless, calculating,
# Nearest to two: per, deorum, christoffel, outsource, synergies, robby, tablets, nonresident,
# Nearest to will: passively, drunk, spoon, pita, happened, forrester, disproven, magistracies,
# Nearest to used: uses, seen, versions, menahem, recessive, armas, arlington, carpenters,
# Nearest to people: downplay, fabaceae, treacherous, hod, economies, tessa, autodidacts, afrikaners,
# Nearest to new: york, speleology, rica, dubois, bombay, ytterbium, slashes, gloss,
# Nearest to over: dominatrixes, clouds, studi, acura, pentagram, cyrenaica, computes, gumby,
# Nearest to proposed: emu, intercourse, clav, synthesisers, underworld, gorgosaurus, theories, leibniz,
# Nearest to grand: lodgings, bournemouth, hugh, throttle, conversing, forl, tempus, evesham,
# Nearest to orthodox: noteworthy, eretria, irenaeus, stab, packaged, abduction, soter, completion,
# Nearest to rise: rising, onslaught, perk, angelico, pedestrian, blackbird, directions, cheese,
# Nearest to defense: parliamentarians, loi, doraemon, leicestershire, commencement, defence, erfurt, kenilworth,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, wheelbase, plankalk,
# Nearest to arts: art, qa, blogger, unger, exported, luddites, lesser, covenanters,
# Nearest to magazine: brinton, marvelman, slade, tristan, navies, environmentalist, regionalism, abiotic,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 4.0880 0.3658 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 4.1357 0.3605 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 4.0757 0.3613 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 4.1125 0.3606 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 4.1114 0.3610 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 4.0920 0.3606 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 4.1347 0.3598 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 4.1368 0.3616 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 4.0996 0.3620 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 3.9671 0.3637 sec/batch
# Nearest to one: kwh, aylwin, freas, apec, estimate, semen, vanished, stakeholders,
# Nearest to where: correspondent, ambrogio, leftrightarrow, bermudez, when, rigour, osprey, innately,
# Nearest to two: per, christoffel, four, synergies, deorum, robby, outsource, bulldogs,
# Nearest to will: spoon, pita, drunk, passively, happened, forrester, magistracies, disproven,
# Nearest to used: uses, seen, menahem, versions, recessive, arlington, armas, carpenters,
# Nearest to people: downplay, fabaceae, treacherous, economies, hod, afrikaners, divus, autodidacts,
# Nearest to new: york, speleology, rica, bombay, gloss, ytterbium, slashes, dubois,
# Nearest to over: dominatrixes, studi, cyrenaica, pentagram, clouds, acura, expectancy, dwt,
# Nearest to proposed: emu, intercourse, clav, synthesisers, underworld, gorgosaurus, theories, moons,
# Nearest to grand: lodgings, bournemouth, hugh, throttle, conversing, tempus, forl, evesham,
# Nearest to orthodox: noteworthy, eretria, irenaeus, soter, stab, ethiopic, packaged, abduction,
# Nearest to rise: rising, onslaught, perk, blackbird, angelico, kreutzmann, directions, pedestrian,
# Nearest to defense: parliamentarians, loi, leicestershire, doraemon, defence, commencement, erfurt, kenilworth,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, resident, plankalk,
# Nearest to arts: art, qa, unger, blogger, exported, luddites, lesser, baleen,
# Nearest to magazine: brinton, marvelman, tristan, slade, navies, regionalism, dustin, environmentalist,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 4.1442 0.3663 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 4.1884 0.3610 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 4.1707 0.3602 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 4.1693 0.3601 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 4.1629 0.3605 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 4.1441 0.3597 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 4.1081 0.3625 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 4.0078 0.3594 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 4.0101 0.3586 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 4.1036 0.3609 sec/batch
# Nearest to one: kwh, aylwin, apec, freas, stakeholders, estimate, fulda, totalling,
# Nearest to where: correspondent, ambrogio, leftrightarrow, when, bermudez, rigour, tenedos, innately,
# Nearest to two: four, per, christoffel, synergies, robby, bulldogs, deorum, nonresident,
# Nearest to will: pita, spoon, passively, drunk, forrester, happened, magistracies, machu,
# Nearest to used: uses, seen, menahem, recessive, versions, correspondents, referred, hominin,
# Nearest to people: downplay, economies, fabaceae, treacherous, hod, afrikaners, divus, autodidacts,
# Nearest to new: york, speleology, rica, gloss, dubois, bombay, rajput, presentations,
# Nearest to over: dominatrixes, studi, pentagram, cyrenaica, expectancy, antipsychotic, gumby, clouds,
# Nearest to proposed: emu, intercourse, synthesisers, clav, theories, gorgosaurus, underworld, leibniz,
# Nearest to grand: lodgings, bournemouth, throttle, hugh, conversing, forl, tempus, evesham,
# Nearest to orthodox: noteworthy, irenaeus, soter, stab, eretria, ethiopic, completion, abduction,
# Nearest to rise: rising, onslaught, perk, blackbird, directions, cheese, manage, kreutzmann,
# Nearest to defense: parliamentarians, loi, leicestershire, doraemon, defence, commencement, erfurt, kenilworth,
# Nearest to accepted: rarities, bulgogi, elrond, opentype, anicetus, adhere, plankalk, resident,
# Nearest to arts: art, unger, qa, blogger, lesser, luddites, exported, covenanters,
# Nearest to magazine: brinton, marvelman, tristan, navies, slade, regionalism, dustin, environmentalist,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 4.0758 0.3662 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 4.1076 0.3612 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 4.0272 0.3610 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 4.1346 0.3617 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 4.1091 0.3648 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 4.1274 0.3639 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 4.1105 0.3604 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 4.1533 0.3610 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 4.0504 0.3609 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 4.0854 0.3603 sec/batch
# Nearest to one: kwh, aylwin, freas, picabia, buonarroti, pickering, bfi, sonnenfeld,
# Nearest to where: correspondent, ambrogio, leftrightarrow, when, rigour, calculating, tenedos, harmless,
# Nearest to two: christoffel, deorum, robby, four, per, bulldogs, synergies, downed,
# Nearest to will: passively, spoon, pita, drunk, forrester, happened, discus, parole,
# Nearest to used: uses, seen, correspondents, menahem, referred, recessive, hominin, armas,
# Nearest to people: downplay, fabaceae, hod, economies, autodidacts, divus, afrikaners, treacherous,
# Nearest to new: york, speleology, dubois, rica, gloss, slashes, silverman, burr,
# Nearest to over: dominatrixes, pentagram, antipsychotic, clouds, studi, gumby, acura, deployable,
# Nearest to proposed: emu, intercourse, synthesisers, theories, gorgosaurus, underworld, clav, predict,
# Nearest to grand: lodgings, bournemouth, hugh, throttle, conversing, forl, tempus, agglomerations,
# Nearest to orthodox: noteworthy, irenaeus, soter, eretria, packaged, stab, completion, abduction,
# Nearest to rise: rising, onslaught, perk, directions, blackbird, manage, cheese, angelico,
# Nearest to defense: parliamentarians, loi, leicestershire, doraemon, commencement, erfurt, defence, kenilworth,
# Nearest to accepted: rarities, bulgogi, elrond, anicetus, opentype, recognized, adhere, plankalk,
# Nearest to arts: art, unger, qa, blogger, parkland, lesser, luddites, exported,
# Nearest to magazine: brinton, marvelman, tristan, slade, kleiner, navies, dustin, regionalism,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 4.1311 0.3656 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 4.1356 0.3624 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 4.1538 0.3618 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 4.1013 0.3634 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 4.0525 0.3609 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 4.0458 0.3637 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 4.1318 0.3618 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 4.1090 0.3612 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 4.1535 0.3609 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 4.0569 0.3599 sec/batch
# Nearest to one: kwh, aylwin, freas, estimate, picabia, stakeholders, letsie, apec,
# Nearest to where: correspondent, ambrogio, leftrightarrow, when, bermudez, rigour, tenedos, harmless,
# Nearest to two: deorum, four, christoffel, synergies, robby, per, bulldogs, nonresident,
# Nearest to will: passively, spoon, forrester, pita, happened, drunk, machu, einhard,
# Nearest to used: uses, seen, correspondents, hominin, menahem, referred, arlington, recessive,
# Nearest to people: downplay, economies, afrikaners, autodidacts, fabaceae, hod, krakow, treacherous,
# Nearest to new: york, speleology, gloss, dubois, rica, burr, slashes, bombay,
# Nearest to over: pentagram, studi, dominatrixes, antipsychotic, expectancy, gumby, clouds, deployable,
# Nearest to proposed: emu, intercourse, theories, synthesisers, gorgosaurus, underworld, clav, predict,
# Nearest to grand: lodgings, bournemouth, throttle, hugh, conversing, tempus, finlandia, forl,
# Nearest to orthodox: eretria, soter, noteworthy, oriental, completion, packaged, isin, xinjiang,
# Nearest to rise: rising, onslaught, perk, directions, blackbird, kreutzmann, manage, cheese,
# Nearest to defense: parliamentarians, loi, leicestershire, defence, doraemon, commencement, kenilworth, adolphe,
# Nearest to accepted: rarities, bulgogi, anicetus, elrond, opentype, recognized, adhere, resident,
# Nearest to arts: art, unger, qa, lesser, blogger, parkland, luddites, exported,
# Nearest to magazine: brinton, marvelman, tristan, kleiner, slade, dustin, environmentalist, navies,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 4.0878 0.3654 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 4.1354 0.3637 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 3.9945 0.3607 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 4.1479 0.3624 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 4.0977 0.3617 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 3.9937 0.3613 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 4.1298 0.3614 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 4.1058 0.3604 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 4.1774 0.3636 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 4.1039 0.3600 sec/batch
# Nearest to one: kwh, aylwin, estimate, freas, apec, stakeholders, lzw, gallon,
# Nearest to where: correspondent, ambrogio, when, leftrightarrow, bermudez, harmless, rigour, arnhem,
# Nearest to two: deorum, four, christoffel, synergies, robby, per, nonresident, tabulate,
# Nearest to will: passively, spoon, pita, forrester, drunk, happened, machu, einhard,
# Nearest to used: uses, seen, correspondents, arlington, hominin, referred, menahem, armas,
# Nearest to people: downplay, afrikaners, autodidacts, economies, fabaceae, hod, treacherous, krakow,
# ...
# Nearest to proposed: suggested, bylaw, parsimonious, sanitization, theories, designs, labeling, abandoned,
# Nearest to grand: crossover, lodgings, vilas, bournemouth, motorsports, cfr, wane, grande,
# Nearest to orthodox: hacked, rooks, hallows, xinjiang, snap, vilna, grape, narbonne,
# Nearest to rise: rising, perk, onslaught, manage, indeed, name, adipose, rises,
# Nearest to defense: defence, regan, gras, leicestershire, doraemon, holds, loi, bh,
# Nearest to accepted: recognized, adhere, regarded, rejected, robins, bulgogi, stopped, used,
# Nearest to arts: art, savate, chun, martial, unger, wallingford, wushu, lesser,
# Nearest to magazine: newsweek, ebay, businessweek, paean, esquire, marvelman, anomaly, issue,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 3.9146 0.3684 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 3.9306 0.3635 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 3.8797 0.3614 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 3.9392 0.3637 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 3.8873 0.3627 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 3.8895 0.3620 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 3.7734 0.3635 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 3.9339 0.3611 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 3.9489 0.3629 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 3.9477 0.3619 sec/batch
# Nearest to one: two, nine, eight, seven, zero, three, four, six,
# Nearest to where: when, then, in, if, arnhem, leftrightarrow, paracompact, he,
# Nearest to two: one, zero, three, four, seven, five, six, eight,
# Nearest to will: would, might, can, does, must, mulk, could, likely,
# Nearest to used: referred, use, uses, seen, using, employed, coined, able,
# Nearest to people: autodidacts, injuring, afrikaners, politicians, someone, nagorno, economies, directors,
# Nearest to new: york, brooklyn, upstate, bronx, speleology, enquiries, berkley, choosing,
# Nearest to over: within, clem, hundred, hani, bahamas, ago, studi, rx,
# Nearest to proposed: suggested, bylaw, theories, parsimonious, sanitization, approved, designs, proposals,
# Nearest to grand: crossover, lodgings, bournemouth, motorsports, vilas, wane, grande, cfr,
# Nearest to orthodox: vilna, hacked, rooks, grape, enco, hallows, isin, xinjiang,
# Nearest to rise: rising, perk, onslaught, manage, name, indeed, fall, adipose,
# Nearest to defense: defence, gras, regan, leicestershire, doraemon, holds, bh, loi,
# Nearest to accepted: recognized, adhere, regarded, rejected, robins, bulgogi, believed, stopped,
# Nearest to arts: art, savate, unger, chun, martial, wallingford, wushu, lesser,
# Nearest to magazine: newsweek, ebay, issue, paean, resides, esquire, businessweek, environmentalist,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 3.9531 0.3660 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 3.9313 0.3632 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 3.9737 0.3631 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 3.9132 0.3628 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 3.8524 0.3648 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 3.7497 0.3627 sec/batch
# Epoch 10/10 Iteration: 77700 Avg. Training loss: 3.8568 0.3610 sec/batch
# Epoch 10/10 Iteration: 77800 Avg. Training loss: 3.8826 0.3614 sec/batch
# Epoch 10/10 Iteration: 77900 Avg. Training loss: 3.9073 0.3638 sec/batch
# Epoch 10/10 Iteration: 78000 Avg. Training loss: 3.7857 0.3620 sec/batch
# Nearest to one: two, nine, eight, three, zero, seven, six, four,
# Nearest to where: when, then, in, leftrightarrow, arnhem, quantifiers, if, paracompact,
# Nearest to two: one, zero, three, four, five, six, seven, eight,
# Nearest to will: would, can, might, does, must, mulk, tends, likely,
# Nearest to used: use, referred, uses, seen, employed, using, coined, refers,
# Nearest to people: afrikaners, autodidacts, injuring, nagorno, marginalised, economies, politicians, players,
# Nearest to new: york, upstate, brooklyn, speleology, bronx, enquiries, reinhold, berkley,
# Nearest to over: within, hundred, clem, bahamas, hani, ago, dewan, agnelli,
# Nearest to proposed: suggested, bylaw, approved, sanitization, parsimonious, introduced, theories, adopted,
# Nearest to grand: crossover, lodgings, cfr, bournemouth, motorsports, vilas, absent, afyon,
# Nearest to orthodox: rooks, hacked, grape, vilna, petrarch, enco, xinjiang, isin,
# Nearest to rise: rising, perk, onslaught, manage, name, indeed, bookshelf, adipose,
# Nearest to defense: defence, gras, regan, leicestershire, loi, militaries, doraemon, bh,
# Nearest to accepted: recognized, adhere, regarded, rejected, robins, bulgogi, seen, blau,
# Nearest to arts: art, savate, unger, wallingford, chun, martial, wushu, lesser,
# Nearest to magazine: newsweek, environmentalist, ebay, businessweek, issue, esquire, resides, paean,
# Epoch 10/10 Iteration: 78100 Avg. Training loss: 3.8976 0.3693 sec/batch
# Epoch 10/10 Iteration: 78200 Avg. Training loss: 3.9124 0.3625 sec/batch
# Epoch 10/10 Iteration: 78300 Avg. Training loss: 3.9179 0.3627 sec/batch
# Epoch 10/10 Iteration: 78400 Avg. Training loss: 3.9233 0.3624 sec/batch
# Epoch 10/10 Iteration: 78500 Avg. Training loss: 3.9531 0.3625 sec/batch
# Epoch 10/10 Iteration: 78600 Avg. Training loss: 3.8424 0.3632 sec/batch
# Epoch 10/10 Iteration: 78700 Avg. Training loss: 3.9071 0.3642 sec/batch
# Epoch 10/10 Iteration: 78800 Avg. Training loss: 3.8743 0.3624 sec/batch
# Epoch 10/10 Iteration: 78900 Avg. Training loss: 3.9427 0.3623 sec/batch
# Epoch 10/10 Iteration: 79000 Avg. Training loss: 3.9763 0.3647 sec/batch
# Nearest to one: two, nine, eight, seven, six, three, zero, four,
# Nearest to where: when, in, then, leftrightarrow, if, paracompact, quantifiers, arnhem,
# Nearest to two: one, zero, three, four, five, seven, six, eight,
# Nearest to will: would, can, might, does, must, mulk, likely, tends,
# Nearest to used: referred, use, uses, seen, employed, coined, using, refers,
# Nearest to people: autodidacts, injuring, afrikaners, economies, politicians, nagorno, someone, marginalised,
# Nearest to new: york, upstate, brooklyn, bronx, speleology, berkley, presentations, enquiries,
# Nearest to over: within, clem, hundred, agnelli, bahamas, dewan, ago, hani,
# Nearest to proposed: suggested, parsimonious, theories, bylaw, approved, sanitization, designs, might,
# Nearest to grand: crossover, cfr, lodgings, bournemouth, bayle, motorsports, grande, interdependence,
# Nearest to orthodox: hacked, orthodoxy, petrarch, rooks, enco, snap, vilna, isin,
# Nearest to rise: rising, perk, onslaught, manage, fall, name, adipose, amplifies,
# Nearest to defense: defence, regan, gras, leicestershire, loi, doraemon, holds, sites,
# Nearest to accepted: recognized, adhere, regarded, rejected, robins, bulgogi, stopped, blau,
# Nearest to arts: art, savate, unger, chun, wallingford, martial, wushu, unparalleled,
# Nearest to magazine: newsweek, businessweek, environmentalist, issue, resides, ebay, anomaly, esquire,
# Epoch 10/10 Iteration: 79100 Avg. Training loss: 3.9357 0.3675 sec/batch
# Epoch 10/10 Iteration: 79200 Avg. Training loss: 3.8389 0.3639 sec/batch
# Epoch 10/10 Iteration: 79300 Avg. Training loss: 3.8801 0.3644 sec/batch
# Epoch 10/10 Iteration: 79400 Avg. Training loss: 3.9276 0.3634 sec/batch
# Epoch 10/10 Iteration: 79500 Avg. Training loss: 3.8743 0.3634 sec/batch
# Epoch 10/10 Iteration: 79600 Avg. Training loss: 3.9288 0.3620 sec/batch
# Epoch 10/10 Iteration: 79700 Avg. Training loss: 3.8424 0.3625 sec/batch
# Epoch 10/10 Iteration: 79800 Avg. Training loss: 3.8931 0.3648 sec/batch
# Epoch 10/10 Iteration: 79900 Avg. Training loss: 3.9438 0.3627 sec/batch
# Epoch 10/10 Iteration: 80000 Avg. Training loss: 3.7896 0.3612 sec/batch
# Nearest to one: nine, two, eight, seven, three, six, zero, four,
# Nearest to where: when, in, then, arnhem, leftrightarrow, if, at, near,
# Nearest to two: one, zero, three, four, five, seven, six, eight,
# Nearest to will: would, can, might, must, does, mulk, likely, shall,
# Nearest to used: use, referred, uses, seen, coined, employed, using, refers,
# Nearest to people: afrikaners, autodidacts, injuring, economies, marginalised, politicians, nagorno, blackface,
# Nearest to new: york, upstate, brooklyn, speleology, enquiries, bronx, berkley, presentations,
# Nearest to over: within, hundred, clem, studi, hani, rx, agnelli, ago,
# Nearest to proposed: suggested, parsimonious, approved, adopted, theories, bylaw, stradonitz, sanitization,
# Nearest to grand: crossover, bournemouth, lodgings, cfr, grande, motorsports, teutonic, bayle,
# Nearest to orthodox: orthodoxy, petrarch, hallows, snap, vilna, hacked, sundays, grape,
# Nearest to rise: rising, perk, onslaught, manage, fall, name, adipose, certain,
# Nearest to defense: defence, regan, gras, leicestershire, loi, sites, doraemon, militaries,
# Nearest to accepted: recognized, adhere, regarded, rejected, robins, used, bulgogi, stopped,
# Nearest to arts: art, savate, unger, chun, wallingford, martial, unparalleled, lesser,
# Nearest to magazine: newsweek, environmentalist, resides, businessweek, ebay, anomaly, esquire, issue,
# Epoch 10/10 Iteration: 80100 Avg. Training loss: 3.9408 0.3686 sec/batch
# Epoch 10/10 Iteration: 80200 Avg. Training loss: 3.9030 0.3633 sec/batch
# Epoch 10/10 Iteration: 80300 Avg. Training loss: 3.8118 0.3612 sec/batch
# Epoch 10/10 Iteration: 80400 Avg. Training loss: 3.9593 0.3642 sec/batch
# Epoch 10/10 Iteration: 80500 Avg. Training loss: 3.9138 0.3625 sec/batch
# Epoch 10/10 Iteration: 80600 Avg. Training loss: 3.9520 0.3620 sec/batch
# Epoch 10/10 Iteration: 80700 Avg. Training loss: 3.9289 0.3645 sec/batch
# Epoch 10/10 Iteration: 80800 Avg. Training loss: 3.8680 0.3618 sec/batch
# Epoch 10/10 Iteration: 80900 Avg. Training loss: 3.9429 0.3622 sec/batch
# Epoch 10/10 Iteration: 81000 Avg. Training loss: 3.8967 0.3642 sec/batch
# Nearest to one: two, nine, eight, seven, three, zero, four, six,
# Nearest to where: when, in, then, arnhem, near, he, elsewhere, if,
# Nearest to two: one, zero, three, four, five, seven, six, eight,
# Nearest to will: would, might, can, must, does, mulk, likely, shall,
# Nearest to used: use, uses, referred, seen, using, employed, coined, believed,
# Nearest to people: afrikaners, autodidacts, injuring, economies, politicians, marginalised, nagorno, persons,
# Nearest to new: york, upstate, brooklyn, reinhold, enquiries, speleology, berkley, bronx,
# Nearest to over: within, hundred, studi, clem, hani, ago, rx, moh,
# Nearest to proposed: suggested, approved, adopted, parsimonious, introduced, bylaw, theories, proposals,
# Nearest to grand: crossover, bournemouth, grande, cfr, lodgings, teutonic, afyon, motorsports,
# Nearest to orthodox: hacked, petrarch, rooks, orthodoxy, snap, isin, wooden, vilna,
# Nearest to rise: rising, onslaught, perk, manage, name, fall, certain, adipose,
# Nearest to defense: defence, gras, regan, leicestershire, loi, sites, militaries, doraemon,
# Nearest to accepted: recognized, adhere, rejected, regarded, robins, bulgogi, blau, stopped,
# Nearest to arts: art, savate, unger, wallingford, martial, chun, lesser, wushu,
# Nearest to magazine: newsweek, businessweek, resides, environmentalist, esquire, ebay, anomaly, paean,
# Epoch 10/10 Iteration: 81100 Avg. Training loss: 3.9472 0.3656 sec/batch
# Epoch 10/10 Iteration: 81200 Avg. Training loss: 3.9273 0.3628 sec/batch
# Epoch 10/10 Iteration: 81300 Avg. Training loss: 3.9268 0.3621 sec/batch
# Epoch 10/10 Iteration: 81400 Avg. Training loss: 3.8414 0.3617 sec/batch
# Epoch 10/10 Iteration: 81500 Avg. Training loss: 3.8869 0.3633 sec/batch
# Epoch 10/10 Iteration: 81600 Avg. Training loss: 3.8992 0.3599 sec/batch
# Epoch 10/10 Iteration: 81700 Avg. Training loss: 3.8584 0.3606 sec/batch
# Epoch 10/10 Iteration: 81800 Avg. Training loss: 3.9313 0.3617 sec/batch
# Epoch 10/10 Iteration: 81900 Avg. Training loss: 3.7174 0.3616 sec/batch
# Epoch 10/10 Iteration: 82000 Avg. Training loss: 3.8269 0.3647 sec/batch
# Nearest to one: two, nine, eight, seven, three, four, zero, six,
# Nearest to where: when, then, in, he, arnhem, at, near, elsewhere,
# Nearest to two: one, zero, three, four, five, seven, six, eight,
# Nearest to will: would, can, might, must, mulk, does, likely, shall,
# Nearest to used: use, uses, referred, employed, seen, using, coined, believed,
# Nearest to people: autodidacts, injuring, afrikaners, politicians, economies, actors, persons, directors,
# Nearest to new: york, brooklyn, upstate, times, bronx, berkley, rajput, reinhold,
# Nearest to over: within, hundred, clem, hani, ago, studi, bahamas, colo,
# Nearest to proposed: suggested, parsimonious, approved, adopted, designs, introduced, theories, proposals,
# Nearest to grand: crossover, grande, bournemouth, cfr, motorsports, teutonic, lodgings, afyon,
# Nearest to orthodox: rooks, vilna, orthodoxy, wooden, hallows, xinjiang, kabbalist, petrarch,
# Nearest to rise: rising, perk, onslaught, manage, fall, name, wolpert, certain,
# Nearest to defense: defence, gras, regan, leicestershire, loi, sites, militaries, holds,
# Nearest to accepted: recognized, adhere, rejected, regarded, robins, bulgogi, used, blau,
# Nearest to arts: art, savate, wallingford, unger, martial, chun, wushu, unparalleled,
# Nearest to magazine: newsweek, businessweek, resides, environmentalist, paean, anomaly, esquire, magazines,
# Epoch 10/10 Iteration: 82100 Avg. Training loss: 3.9479 0.3673 sec/batch
# Epoch 10/10 Iteration: 82200 Avg. Training loss: 3.9735 0.3637 sec/batch
# Epoch 10/10 Iteration: 82300 Avg. Training loss: 3.9663 0.3632 sec/batch
# Epoch 10/10 Iteration: 82400 Avg. Training loss: 3.9962 0.3648 sec/batch
# Epoch 10/10 Iteration: 82500 Avg. Training loss: 3.9576 0.3626 sec/batch
# Epoch 10/10 Iteration: 82600 Avg. Training loss: 3.8117 0.3626 sec/batch
# Epoch 10/10 Iteration: 82700 Avg. Training loss: 3.9345 0.3636 sec/batch
# Epoch 10/10 Iteration: 82800 Avg. Training loss: 3.8480 0.3613 sec/batch
# Epoch 10/10 Iteration: 82900 Avg. Training loss: 3.8857 0.3598 sec/batch
# Epoch 10/10 Iteration: 83000 Avg. Training loss: 3.9327 0.3612 sec/batch
# Nearest to one: two, nine, eight, seven, three, zero, four, six,
# Nearest to where: when, then, in, paracompact, arnhem, leftrightarrow, if, near,
# Nearest to two: one, zero, three, four, seven, five, six, eight,
# Nearest to will: would, might, can, must, does, mulk, seems, likely,
# Nearest to used: use, uses, referred, seen, employed, using, coined, able,
# Nearest to people: autodidacts, afrikaners, politicians, injuring, atheists, diabetics, directors, economies,
# Nearest to new: york, upstate, brooklyn, bronx, times, berkley, rajput, speleology,
# Nearest to over: within, hundred, clem, hani, ago, havoc, bahamas, colo,
# Nearest to proposed: suggested, approved, parsimonious, adopted, theories, sanitization, designs, proposals,
# Nearest to grand: crossover, grande, bournemouth, cfr, afyon, motorsports, teutonic, lodgings,
# Nearest to orthodox: xinjiang, wooden, rooks, snap, petrarch, kabbalist, tee, eretria,
# Nearest to rise: rising, perk, manage, onslaught, fall, name, adipose, certain,
# Nearest to defense: defence, gras, regan, leicestershire, loi, holds, doraemon, sites,
# Nearest to accepted: recognized, adhere, rejected, regarded, robins, used, bulgogi, offered,
# Nearest to arts: art, savate, unger, wushu, wallingford, martial, chun, gaited,
# Nearest to magazine: newsweek, businessweek, resides, environmentalist, ebay, esquire, paean, anomaly,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 3.8766 0.3672 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 3.6660 0.3630 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 3.9442 0.3619 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 3.8475 0.3629 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 3.9220 0.3617 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 3.8899 0.3602 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 3.8922 0.3617 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 3.9296 0.3625 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
