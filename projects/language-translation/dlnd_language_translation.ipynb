# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    def one_sentence_to_id(sentence, lookup, target=False):
        sentence_id = [lookup.get(word, lookup['<UNK>']) for word in sentence.split(' ')]
        return sentence_id + [lookup['<EOS>'], ] if target else sentence_id

    source_id_text = [one_sentence_to_id(s, source_vocab_to_int) for s in source_text.split('\n')]
    target_id_text = [one_sentence_to_id(s, target_vocab_to_int, True) for s in target_text.split('\n')]

    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# /home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, [None, ], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, [None, ], name='source_sequence_length')
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/traitlets/config/application.py", line 653, in launch_instance\n    app.start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-83-f7ba07ea97ce>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/carnd/deep-learning/language-translation/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/home/c ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/traitlets/config/application.py", line 653, in launch_instance\n    app.start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-83-f7ba07ea97ce>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/carnd/deep-learning/language-translation/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/home/c ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/traitlets/config/application.py", line 653, in launch_instance\n    app.start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-83-f7ba07ea97ce>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/carnd/deep-learning/language-translation/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'Fil ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/carnd/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/traitlets/config/application.py", line 653, in launch_instance\n    app.start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-83-f7ba07ea97ce>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/carnd/deep-learning/language-translation/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/home/carnd/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'Fil ...
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    trimmed_target_data = tf.strided_slice(target_data, begin=[0, 0], end=[batch_size, -1], strides=[1, 1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    preprocessed_target_data = tf.concat([go, trimmed_target_data], axis=1)
    return preprocessed_target_data

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def create_lstm_cell(cell_size, keep_prob=None):
    """ function for creating single lstm cell, (optionally with DropoutWrapper)"""
    lstm_cell = tf.contrib.rnn.LSTMCell(cell_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
    if keep_prob is not None:
        lstm_cell = tf.contrib.rnn.DropoutWrapper(lstm_cell, output_keep_prob=keep_prob)
    
    return lstm_cell


def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, vocab_size=source_vocab_size,
                                                   embed_dim=encoding_embedding_size)
    
    lstm_layer = tf.contrib.rnn.MultiRNNCell([create_lstm_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    rnn_output, rnn_state = tf.nn.dynamic_rnn(lstm_layer, inputs=embed_input,
                                              sequence_length=source_sequence_length,
                                              dtype=tf.float32)
    
    return rnn_output, rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length, name='training_helper')
    decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell, helper=helper,
                                              initial_state=encoder_state, output_layer=output_layer)
    outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(decoder, maximum_iterations=max_summary_length,
                                                      impute_finished=True)
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_tokens = tf.tile([start_of_sequence_id], [batch_size], name='start_tokens')
    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding=dec_embeddings, start_tokens=start_tokens,
                                                      end_token=end_of_sequence_id)
    decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell, helper=helper, initial_state=encoder_state,
                                              output_layer=output_layer)
    outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(decoder, maximum_iterations=max_target_sequence_length,
                                                      impute_finished=True)
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function

    # embed the target sequences
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    # construct the decoder LSTM cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([create_lstm_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    # create an output layer
    output_layer = Dense(target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    # setup training decoder
    with tf.variable_scope('decoder'):
        training_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input,
                                               target_sequence_length, max_target_sequence_length,
                                               output_layer, keep_prob)
    
    # setup inference decoder, which will share the variables with training decoder
    with tf.variable_scope('decoder', reuse=True):
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings,
                                                start_of_sequence_id, end_of_sequence_id,
                                                max_target_sequence_length, target_vocab_size,
                                                output_layer, batch_size, keep_prob)
    
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # encode the input
    enc_output, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob,
                                           source_sequence_length, source_vocab_size, enc_embedding_size)
    
    # process target data
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # decode the encoded input
    training_output, inference_output = decoding_layer(dec_input, enc_state,
                                                       target_sequence_length,
                                                       max_target_sentence_length,
                                                       rnn_size, num_layers,
                                                       target_vocab_to_int,
                                                       target_vocab_size, batch_size,
                                                       keep_prob, dec_embedding_size)
    
    return training_output, inference_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 50
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 50
decoding_embedding_size = 50
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 1
display_step = 20

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   20/269 - Train Accuracy: 0.3269, Validation Accuracy: 0.3881, Loss: 3.0551
# Epoch   0 Batch   40/269 - Train Accuracy: 0.3557, Validation Accuracy: 0.4137, Loss: 2.6882
# Epoch   0 Batch   60/269 - Train Accuracy: 0.4289, Validation Accuracy: 0.4485, Loss: 2.2534
# Epoch   0 Batch   80/269 - Train Accuracy: 0.4850, Validation Accuracy: 0.4985, Loss: 2.0383
# Epoch   0 Batch  100/269 - Train Accuracy: 0.4902, Validation Accuracy: 0.4888, Loss: 1.8397
# Epoch   0 Batch  120/269 - Train Accuracy: 0.4191, Validation Accuracy: 0.4750, Loss: 1.7591
# Epoch   0 Batch  140/269 - Train Accuracy: 0.4429, Validation Accuracy: 0.4663, Loss: 1.4919
# Epoch   0 Batch  160/269 - Train Accuracy: 0.4614, Validation Accuracy: 0.4817, Loss: 1.2326
# Epoch   0 Batch  180/269 - Train Accuracy: 0.4725, Validation Accuracy: 0.4891, Loss: 1.0103
# Epoch   0 Batch  200/269 - Train Accuracy: 0.4739, Validation Accuracy: 0.5112, Loss: 0.9306
# Epoch   0 Batch  220/269 - Train Accuracy: 0.5493, Validation Accuracy: 0.5417, Loss: 0.7756
# Epoch   0 Batch  240/269 - Train Accuracy: 0.5951, Validation Accuracy: 0.5761, Loss: 0.7004
# Epoch   0 Batch  260/269 - Train Accuracy: 0.5678, Validation Accuracy: 0.6017, Loss: 0.7370
# Epoch   1 Batch   20/269 - Train Accuracy: 0.5945, Validation Accuracy: 0.6110, Loss: 0.6763
# Epoch   1 Batch   40/269 - Train Accuracy: 0.6017, Validation Accuracy: 0.6201, Loss: 0.6488
# Epoch   1 Batch   60/269 - Train Accuracy: 0.6387, Validation Accuracy: 0.6324, Loss: 0.5664
# Epoch   1 Batch   80/269 - Train Accuracy: 0.6430, Validation Accuracy: 0.6475, Loss: 0.5548
# Epoch   1 Batch  100/269 - Train Accuracy: 0.6685, Validation Accuracy: 0.6499, Loss: 0.5273
# Epoch   1 Batch  120/269 - Train Accuracy: 0.6481, Validation Accuracy: 0.6713, Loss: 0.5215
# Epoch   1 Batch  140/269 - Train Accuracy: 0.6651, Validation Accuracy: 0.6694, Loss: 0.4965
# Epoch   1 Batch  160/269 - Train Accuracy: 0.6740, Validation Accuracy: 0.6812, Loss: 0.4623
# Epoch   1 Batch  180/269 - Train Accuracy: 0.6774, Validation Accuracy: 0.6844, Loss: 0.4428
# Epoch   1 Batch  200/269 - Train Accuracy: 0.6725, Validation Accuracy: 0.6952, Loss: 0.4432
# Epoch   1 Batch  220/269 - Train Accuracy: 0.6949, Validation Accuracy: 0.7008, Loss: 0.3901
# Epoch   1 Batch  240/269 - Train Accuracy: 0.7144, Validation Accuracy: 0.6984, Loss: 0.3597
# Epoch   1 Batch  260/269 - Train Accuracy: 0.6933, Validation Accuracy: 0.7110, Loss: 0.3925
# Epoch   2 Batch   20/269 - Train Accuracy: 0.7096, Validation Accuracy: 0.7185, Loss: 0.3738
# Epoch   2 Batch   40/269 - Train Accuracy: 0.7265, Validation Accuracy: 0.7411, Loss: 0.3582
# Epoch   2 Batch   60/269 - Train Accuracy: 0.7438, Validation Accuracy: 0.7478, Loss: 0.3097
# Epoch   2 Batch   80/269 - Train Accuracy: 0.7490, Validation Accuracy: 0.7457, Loss: 0.3065
# Epoch   2 Batch  100/269 - Train Accuracy: 0.7772, Validation Accuracy: 0.7456, Loss: 0.2893
# Epoch   2 Batch  120/269 - Train Accuracy: 0.7560, Validation Accuracy: 0.7576, Loss: 0.2903
# Epoch   2 Batch  140/269 - Train Accuracy: 0.7759, Validation Accuracy: 0.7682, Loss: 0.2853
# Epoch   2 Batch  160/269 - Train Accuracy: 0.7745, Validation Accuracy: 0.7724, Loss: 0.2564
# Epoch   2 Batch  180/269 - Train Accuracy: 0.8026, Validation Accuracy: 0.7873, Loss: 0.2512
# Epoch   2 Batch  200/269 - Train Accuracy: 0.7890, Validation Accuracy: 0.7797, Loss: 0.2502
# Epoch   2 Batch  220/269 - Train Accuracy: 0.8157, Validation Accuracy: 0.8053, Loss: 0.2204
# Epoch   2 Batch  240/269 - Train Accuracy: 0.8195, Validation Accuracy: 0.8078, Loss: 0.1964
# Epoch   2 Batch  260/269 - Train Accuracy: 0.7865, Validation Accuracy: 0.8091, Loss: 0.2157
# Epoch   3 Batch   20/269 - Train Accuracy: 0.8320, Validation Accuracy: 0.8213, Loss: 0.2057
# Epoch   3 Batch   40/269 - Train Accuracy: 0.8161, Validation Accuracy: 0.8235, Loss: 0.2086
# Epoch   3 Batch   60/269 - Train Accuracy: 0.8389, Validation Accuracy: 0.8288, Loss: 0.1761
# Epoch   3 Batch   80/269 - Train Accuracy: 0.8457, Validation Accuracy: 0.8490, Loss: 0.1737
# Epoch   3 Batch  100/269 - Train Accuracy: 0.8618, Validation Accuracy: 0.8475, Loss: 0.1639
# Epoch   3 Batch  120/269 - Train Accuracy: 0.8435, Validation Accuracy: 0.8525, Loss: 0.1679
# Epoch   3 Batch  140/269 - Train Accuracy: 0.8524, Validation Accuracy: 0.8572, Loss: 0.1651
# Epoch   3 Batch  160/269 - Train Accuracy: 0.8750, Validation Accuracy: 0.8746, Loss: 0.1428
# Epoch   3 Batch  180/269 - Train Accuracy: 0.8866, Validation Accuracy: 0.8744, Loss: 0.1375
# Epoch   3 Batch  200/269 - Train Accuracy: 0.8859, Validation Accuracy: 0.8943, Loss: 0.1412
# Epoch   3 Batch  220/269 - Train Accuracy: 0.8836, Validation Accuracy: 0.8813, Loss: 0.1221
# Epoch   3 Batch  240/269 - Train Accuracy: 0.8998, Validation Accuracy: 0.8952, Loss: 0.1124
# Epoch   3 Batch  260/269 - Train Accuracy: 0.8822, Validation Accuracy: 0.8968, Loss: 0.1271
# Epoch   4 Batch   20/269 - Train Accuracy: 0.9009, Validation Accuracy: 0.9042, Loss: 0.1236
# Epoch   4 Batch   40/269 - Train Accuracy: 0.9022, Validation Accuracy: 0.8973, Loss: 0.1217
# Epoch   4 Batch   60/269 - Train Accuracy: 0.9099, Validation Accuracy: 0.8974, Loss: 0.1010
# Epoch   4 Batch   80/269 - Train Accuracy: 0.8940, Validation Accuracy: 0.8964, Loss: 0.1042
# Epoch   4 Batch  100/269 - Train Accuracy: 0.9210, Validation Accuracy: 0.9023, Loss: 0.1024
# Epoch   4 Batch  120/269 - Train Accuracy: 0.8998, Validation Accuracy: 0.8982, Loss: 0.0990
# Epoch   4 Batch  140/269 - Train Accuracy: 0.9006, Validation Accuracy: 0.9072, Loss: 0.1007
# Epoch   4 Batch  160/269 - Train Accuracy: 0.9157, Validation Accuracy: 0.9204, Loss: 0.0822
# Epoch   4 Batch  180/269 - Train Accuracy: 0.9286, Validation Accuracy: 0.9189, Loss: 0.0767
# Epoch   4 Batch  200/269 - Train Accuracy: 0.9239, Validation Accuracy: 0.9236, Loss: 0.0802
# Epoch   4 Batch  220/269 - Train Accuracy: 0.9268, Validation Accuracy: 0.9250, Loss: 0.0705
# Epoch   4 Batch  240/269 - Train Accuracy: 0.9419, Validation Accuracy: 0.9277, Loss: 0.0647
# Epoch   4 Batch  260/269 - Train Accuracy: 0.9216, Validation Accuracy: 0.9365, Loss: 0.0715
# Epoch   5 Batch   20/269 - Train Accuracy: 0.9315, Validation Accuracy: 0.9317, Loss: 0.0666
# Epoch   5 Batch   40/269 - Train Accuracy: 0.9214, Validation Accuracy: 0.9189, Loss: 0.0688
# Epoch   5 Batch   60/269 - Train Accuracy: 0.9432, Validation Accuracy: 0.9256, Loss: 0.0556
# Epoch   5 Batch   80/269 - Train Accuracy: 0.9219, Validation Accuracy: 0.9276, Loss: 0.0560
# Epoch   5 Batch  100/269 - Train Accuracy: 0.9438, Validation Accuracy: 0.9390, Loss: 0.0556
# Epoch   5 Batch  120/269 - Train Accuracy: 0.9270, Validation Accuracy: 0.9316, Loss: 0.0614
# Epoch   5 Batch  140/269 - Train Accuracy: 0.9328, Validation Accuracy: 0.9280, Loss: 0.0614
# Epoch   5 Batch  160/269 - Train Accuracy: 0.9256, Validation Accuracy: 0.9314, Loss: 0.0483
# Epoch   5 Batch  180/269 - Train Accuracy: 0.9453, Validation Accuracy: 0.9361, Loss: 0.0475
# Epoch   5 Batch  200/269 - Train Accuracy: 0.9385, Validation Accuracy: 0.9399, Loss: 0.0497
# Epoch   5 Batch  220/269 - Train Accuracy: 0.9359, Validation Accuracy: 0.9481, Loss: 0.0470
# Epoch   5 Batch  240/269 - Train Accuracy: 0.9456, Validation Accuracy: 0.9465, Loss: 0.0423
# Epoch   5 Batch  260/269 - Train Accuracy: 0.9430, Validation Accuracy: 0.9496, Loss: 0.0449
# Epoch   6 Batch   20/269 - Train Accuracy: 0.9328, Validation Accuracy: 0.9362, Loss: 0.0467
# Epoch   6 Batch   40/269 - Train Accuracy: 0.9324, Validation Accuracy: 0.9438, Loss: 0.0542
# Epoch   6 Batch   60/269 - Train Accuracy: 0.9443, Validation Accuracy: 0.9348, Loss: 0.0404
# Epoch   6 Batch   80/269 - Train Accuracy: 0.9409, Validation Accuracy: 0.9358, Loss: 0.0421
# Epoch   6 Batch  100/269 - Train Accuracy: 0.9504, Validation Accuracy: 0.9480, Loss: 0.0423
# Epoch   6 Batch  120/269 - Train Accuracy: 0.9410, Validation Accuracy: 0.9463, Loss: 0.0452
# Epoch   6 Batch  140/269 - Train Accuracy: 0.9366, Validation Accuracy: 0.9371, Loss: 0.0467
# Epoch   6 Batch  160/269 - Train Accuracy: 0.9501, Validation Accuracy: 0.9474, Loss: 0.0378
# Epoch   6 Batch  180/269 - Train Accuracy: 0.9506, Validation Accuracy: 0.9458, Loss: 0.0358
# Epoch   6 Batch  200/269 - Train Accuracy: 0.9541, Validation Accuracy: 0.9387, Loss: 0.0361
# Epoch   6 Batch  220/269 - Train Accuracy: 0.9479, Validation Accuracy: 0.9531, Loss: 0.0372
# Epoch   6 Batch  240/269 - Train Accuracy: 0.9460, Validation Accuracy: 0.9434, Loss: 0.0352
# Epoch   6 Batch  260/269 - Train Accuracy: 0.9459, Validation Accuracy: 0.9492, Loss: 0.0367
# Epoch   7 Batch   20/269 - Train Accuracy: 0.9534, Validation Accuracy: 0.9376, Loss: 0.0400
# Epoch   7 Batch   40/269 - Train Accuracy: 0.9488, Validation Accuracy: 0.9478, Loss: 0.0433
# Epoch   7 Batch   60/269 - Train Accuracy: 0.9526, Validation Accuracy: 0.9474, Loss: 0.0335
# Epoch   7 Batch   80/269 - Train Accuracy: 0.9433, Validation Accuracy: 0.9295, Loss: 0.0334
# Epoch   7 Batch  100/269 - Train Accuracy: 0.9604, Validation Accuracy: 0.9455, Loss: 0.0348
# Epoch   7 Batch  120/269 - Train Accuracy: 0.9447, Validation Accuracy: 0.9474, Loss: 0.0382
# Epoch   7 Batch  140/269 - Train Accuracy: 0.9418, Validation Accuracy: 0.9522, Loss: 0.0382
# Epoch   7 Batch  160/269 - Train Accuracy: 0.9512, Validation Accuracy: 0.9429, Loss: 0.0329
# Epoch   7 Batch  180/269 - Train Accuracy: 0.9561, Validation Accuracy: 0.9535, Loss: 0.0297
# Epoch   7 Batch  200/269 - Train Accuracy: 0.9602, Validation Accuracy: 0.9552, Loss: 0.0292
# Epoch   7 Batch  220/269 - Train Accuracy: 0.9502, Validation Accuracy: 0.9501, Loss: 0.0323
# Epoch   7 Batch  240/269 - Train Accuracy: 0.9462, Validation Accuracy: 0.9544, Loss: 0.0298
# Epoch   7 Batch  260/269 - Train Accuracy: 0.9521, Validation Accuracy: 0.9540, Loss: 0.0313
# Epoch   8 Batch   20/269 - Train Accuracy: 0.9604, Validation Accuracy: 0.9506, Loss: 0.0300
# Epoch   8 Batch   40/269 - Train Accuracy: 0.9361, Validation Accuracy: 0.9415, Loss: 0.0490
# Epoch   8 Batch   60/269 - Train Accuracy: 0.9478, Validation Accuracy: 0.9383, Loss: 0.0359
# Epoch   8 Batch   80/269 - Train Accuracy: 0.9482, Validation Accuracy: 0.9408, Loss: 0.0312
# Epoch   8 Batch  100/269 - Train Accuracy: 0.9582, Validation Accuracy: 0.9553, Loss: 0.0319
# Epoch   8 Batch  120/269 - Train Accuracy: 0.9536, Validation Accuracy: 0.9533, Loss: 0.0336
# Epoch   8 Batch  140/269 - Train Accuracy: 0.9540, Validation Accuracy: 0.9576, Loss: 0.0348
# Epoch   8 Batch  160/269 - Train Accuracy: 0.9549, Validation Accuracy: 0.9563, Loss: 0.0279
# Epoch   8 Batch  180/269 - Train Accuracy: 0.9584, Validation Accuracy: 0.9564, Loss: 0.0250
# Epoch   8 Batch  200/269 - Train Accuracy: 0.9604, Validation Accuracy: 0.9513, Loss: 0.0257
# Epoch   8 Batch  220/269 - Train Accuracy: 0.9482, Validation Accuracy: 0.9515, Loss: 0.0288
# Epoch   8 Batch  240/269 - Train Accuracy: 0.9537, Validation Accuracy: 0.9431, Loss: 0.0263
# Epoch   8 Batch  260/269 - Train Accuracy: 0.9556, Validation Accuracy: 0.9524, Loss: 0.0281
# Epoch   9 Batch   20/269 - Train Accuracy: 0.9602, Validation Accuracy: 0.9529, Loss: 0.0258
# Epoch   9 Batch   40/269 - Train Accuracy: 0.9415, Validation Accuracy: 0.9484, Loss: 0.0339
# Epoch   9 Batch   60/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9482, Loss: 0.0265
# Epoch   9 Batch   80/269 - Train Accuracy: 0.9526, Validation Accuracy: 0.9461, Loss: 0.0269
# Epoch   9 Batch  100/269 - Train Accuracy: 0.9562, Validation Accuracy: 0.9583, Loss: 0.0278
# Epoch   9 Batch  120/269 - Train Accuracy: 0.9527, Validation Accuracy: 0.9553, Loss: 0.0292
# Epoch   9 Batch  140/269 - Train Accuracy: 0.9516, Validation Accuracy: 0.9522, Loss: 0.0298
# Epoch   9 Batch  160/269 - Train Accuracy: 0.9684, Validation Accuracy: 0.9554, Loss: 0.0239
# Epoch   9 Batch  180/269 - Train Accuracy: 0.9629, Validation Accuracy: 0.9551, Loss: 0.0229
# Epoch   9 Batch  200/269 - Train Accuracy: 0.9660, Validation Accuracy: 0.9559, Loss: 0.0216
# Epoch   9 Batch  220/269 - Train Accuracy: 0.9516, Validation Accuracy: 0.9495, Loss: 0.0253
# Epoch   9 Batch  240/269 - Train Accuracy: 0.9534, Validation Accuracy: 0.9484, Loss: 0.0228
# Epoch   9 Batch  260/269 - Train Accuracy: 0.9633, Validation Accuracy: 0.9574, Loss: 0.0244
# Epoch  10 Batch   20/269 - Train Accuracy: 0.9707, Validation Accuracy: 0.9588, Loss: 0.0230
# Epoch  10 Batch   40/269 - Train Accuracy: 0.9381, Validation Accuracy: 0.9506, Loss: 0.0297
# Epoch  10 Batch   60/269 - Train Accuracy: 0.9623, Validation Accuracy: 0.9575, Loss: 0.0240
# Epoch  10 Batch   80/269 - Train Accuracy: 0.9585, Validation Accuracy: 0.9542, Loss: 0.0225
# Epoch  10 Batch  100/269 - Train Accuracy: 0.9552, Validation Accuracy: 0.9548, Loss: 0.0271
# Epoch  10 Batch  120/269 - Train Accuracy: 0.9589, Validation Accuracy: 0.9608, Loss: 0.0264
# Epoch  10 Batch  140/269 - Train Accuracy: 0.9520, Validation Accuracy: 0.9607, Loss: 0.0269
# Epoch  10 Batch  160/269 - Train Accuracy: 0.9678, Validation Accuracy: 0.9525, Loss: 0.0227
# Epoch  10 Batch  180/269 - Train Accuracy: 0.9686, Validation Accuracy: 0.9623, Loss: 0.0221
# Epoch  10 Batch  200/269 - Train Accuracy: 0.9700, Validation Accuracy: 0.9536, Loss: 0.0207
# Epoch  10 Batch  220/269 - Train Accuracy: 0.9537, Validation Accuracy: 0.9556, Loss: 0.0238
# Epoch  10 Batch  240/269 - Train Accuracy: 0.9631, Validation Accuracy: 0.9524, Loss: 0.0213
# Epoch  10 Batch  260/269 - Train Accuracy: 0.9673, Validation Accuracy: 0.9637, Loss: 0.0209
# Epoch  11 Batch   20/269 - Train Accuracy: 0.9754, Validation Accuracy: 0.9577, Loss: 0.0208
# Epoch  11 Batch   40/269 - Train Accuracy: 0.9420, Validation Accuracy: 0.9559, Loss: 0.0291
# Epoch  11 Batch   60/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9632, Loss: 0.0227
# Epoch  11 Batch   80/269 - Train Accuracy: 0.9558, Validation Accuracy: 0.9558, Loss: 0.0222
# Epoch  11 Batch  100/269 - Train Accuracy: 0.9585, Validation Accuracy: 0.9599, Loss: 0.0229
# Epoch  11 Batch  120/269 - Train Accuracy: 0.9577, Validation Accuracy: 0.9579, Loss: 0.0257
# Epoch  11 Batch  140/269 - Train Accuracy: 0.9553, Validation Accuracy: 0.9537, Loss: 0.0330
# Epoch  11 Batch  160/269 - Train Accuracy: 0.9646, Validation Accuracy: 0.9561, Loss: 0.0247
# Epoch  11 Batch  180/269 - Train Accuracy: 0.9674, Validation Accuracy: 0.9581, Loss: 0.0222
# Epoch  11 Batch  200/269 - Train Accuracy: 0.9696, Validation Accuracy: 0.9621, Loss: 0.0202
# Epoch  11 Batch  220/269 - Train Accuracy: 0.9556, Validation Accuracy: 0.9486, Loss: 0.0233
# Epoch  11 Batch  240/269 - Train Accuracy: 0.9617, Validation Accuracy: 0.9479, Loss: 0.0201
# Epoch  11 Batch  260/269 - Train Accuracy: 0.9651, Validation Accuracy: 0.9540, Loss: 0.0219
# Epoch  12 Batch   20/269 - Train Accuracy: 0.9756, Validation Accuracy: 0.9578, Loss: 0.0187
# Epoch  12 Batch   40/269 - Train Accuracy: 0.9515, Validation Accuracy: 0.9538, Loss: 0.0245
# Epoch  12 Batch   60/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9619, Loss: 0.0208
# Epoch  12 Batch   80/269 - Train Accuracy: 0.9620, Validation Accuracy: 0.9624, Loss: 0.0212
# Epoch  12 Batch  100/269 - Train Accuracy: 0.9586, Validation Accuracy: 0.9650, Loss: 0.0242
# Epoch  12 Batch  120/269 - Train Accuracy: 0.9640, Validation Accuracy: 0.9570, Loss: 0.0237
# Epoch  12 Batch  140/269 - Train Accuracy: 0.9495, Validation Accuracy: 0.9602, Loss: 0.0277
# Epoch  12 Batch  160/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9549, Loss: 0.0186
# Epoch  12 Batch  180/269 - Train Accuracy: 0.9706, Validation Accuracy: 0.9706, Loss: 0.0168
# Epoch  12 Batch  200/269 - Train Accuracy: 0.9752, Validation Accuracy: 0.9653, Loss: 0.0178
# Epoch  12 Batch  220/269 - Train Accuracy: 0.9586, Validation Accuracy: 0.9622, Loss: 0.0210
# Epoch  12 Batch  240/269 - Train Accuracy: 0.9638, Validation Accuracy: 0.9553, Loss: 0.0213
# Epoch  12 Batch  260/269 - Train Accuracy: 0.9678, Validation Accuracy: 0.9534, Loss: 0.0196
# Epoch  13 Batch   20/269 - Train Accuracy: 0.9740, Validation Accuracy: 0.9588, Loss: 0.0210
# Epoch  13 Batch   40/269 - Train Accuracy: 0.9272, Validation Accuracy: 0.9358, Loss: 0.0739
# Epoch  13 Batch   60/269 - Train Accuracy: 0.9562, Validation Accuracy: 0.9482, Loss: 0.0349
# Epoch  13 Batch   80/269 - Train Accuracy: 0.9580, Validation Accuracy: 0.9604, Loss: 0.0247
# Epoch  13 Batch  100/269 - Train Accuracy: 0.9528, Validation Accuracy: 0.9538, Loss: 0.0262
# Epoch  13 Batch  120/269 - Train Accuracy: 0.9584, Validation Accuracy: 0.9577, Loss: 0.0233
# Epoch  13 Batch  140/269 - Train Accuracy: 0.9576, Validation Accuracy: 0.9524, Loss: 0.0233
# Epoch  13 Batch  160/269 - Train Accuracy: 0.9680, Validation Accuracy: 0.9624, Loss: 0.0204
# Epoch  13 Batch  180/269 - Train Accuracy: 0.9733, Validation Accuracy: 0.9704, Loss: 0.0182
# Epoch  13 Batch  200/269 - Train Accuracy: 0.9655, Validation Accuracy: 0.9638, Loss: 0.0194
# Epoch  13 Batch  220/269 - Train Accuracy: 0.9553, Validation Accuracy: 0.9560, Loss: 0.0222
# Epoch  13 Batch  240/269 - Train Accuracy: 0.9725, Validation Accuracy: 0.9593, Loss: 0.0167
# Epoch  13 Batch  260/269 - Train Accuracy: 0.9685, Validation Accuracy: 0.9643, Loss: 0.0189
# Epoch  14 Batch   20/269 - Train Accuracy: 0.9797, Validation Accuracy: 0.9582, Loss: 0.0168
# Epoch  14 Batch   40/269 - Train Accuracy: 0.9516, Validation Accuracy: 0.9600, Loss: 0.0238
# Epoch  14 Batch   60/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9680, Loss: 0.0189
# Epoch  14 Batch   80/269 - Train Accuracy: 0.9713, Validation Accuracy: 0.9601, Loss: 0.0189
# Epoch  14 Batch  100/269 - Train Accuracy: 0.9652, Validation Accuracy: 0.9661, Loss: 0.0196
# Epoch  14 Batch  120/269 - Train Accuracy: 0.9623, Validation Accuracy: 0.9669, Loss: 0.0194
# Epoch  14 Batch  140/269 - Train Accuracy: 0.9590, Validation Accuracy: 0.9646, Loss: 0.0214
# Epoch  14 Batch  160/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9703, Loss: 0.0172
# Epoch  14 Batch  180/269 - Train Accuracy: 0.9723, Validation Accuracy: 0.9743, Loss: 0.0164
# Epoch  14 Batch  200/269 - Train Accuracy: 0.9730, Validation Accuracy: 0.9594, Loss: 0.0170
# Epoch  14 Batch  220/269 - Train Accuracy: 0.9586, Validation Accuracy: 0.9596, Loss: 0.0181
# Epoch  14 Batch  240/269 - Train Accuracy: 0.9585, Validation Accuracy: 0.9521, Loss: 0.0196
# Epoch  14 Batch  260/269 - Train Accuracy: 0.9707, Validation Accuracy: 0.9591, Loss: 0.0172
# Epoch  15 Batch   20/269 - Train Accuracy: 0.9770, Validation Accuracy: 0.9602, Loss: 0.0178
# Epoch  15 Batch   40/269 - Train Accuracy: 0.9503, Validation Accuracy: 0.9646, Loss: 0.0219
# Epoch  15 Batch   60/269 - Train Accuracy: 0.9729, Validation Accuracy: 0.9571, Loss: 0.0202
# Epoch  15 Batch   80/269 - Train Accuracy: 0.9660, Validation Accuracy: 0.9516, Loss: 0.0188
# Epoch  15 Batch  100/269 - Train Accuracy: 0.9639, Validation Accuracy: 0.9661, Loss: 0.0182
# Epoch  15 Batch  120/269 - Train Accuracy: 0.9705, Validation Accuracy: 0.9672, Loss: 0.0174
# Epoch  15 Batch  140/269 - Train Accuracy: 0.9561, Validation Accuracy: 0.9612, Loss: 0.0226
# Epoch  15 Batch  160/269 - Train Accuracy: 0.9768, Validation Accuracy: 0.9672, Loss: 0.0155
# Epoch  15 Batch  180/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9716, Loss: 0.0150
# Epoch  15 Batch  200/269 - Train Accuracy: 0.9751, Validation Accuracy: 0.9640, Loss: 0.0161
# Epoch  15 Batch  220/269 - Train Accuracy: 0.9613, Validation Accuracy: 0.9661, Loss: 0.0177
# Epoch  15 Batch  240/269 - Train Accuracy: 0.9689, Validation Accuracy: 0.9643, Loss: 0.0167
# Epoch  15 Batch  260/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9622, Loss: 0.0179
# Epoch  16 Batch   20/269 - Train Accuracy: 0.9736, Validation Accuracy: 0.9557, Loss: 0.0166
# Epoch  16 Batch   40/269 - Train Accuracy: 0.9591, Validation Accuracy: 0.9591, Loss: 0.0201
# Epoch  16 Batch   60/269 - Train Accuracy: 0.9718, Validation Accuracy: 0.9642, Loss: 0.0188
# Epoch  16 Batch   80/269 - Train Accuracy: 0.9747, Validation Accuracy: 0.9597, Loss: 0.0160
# Epoch  16 Batch  100/269 - Train Accuracy: 0.9699, Validation Accuracy: 0.9640, Loss: 0.0181
# Epoch  16 Batch  120/269 - Train Accuracy: 0.9611, Validation Accuracy: 0.9672, Loss: 0.0160
# Epoch  16 Batch  140/269 - Train Accuracy: 0.9638, Validation Accuracy: 0.9697, Loss: 0.0199
# Epoch  16 Batch  160/269 - Train Accuracy: 0.9776, Validation Accuracy: 0.9661, Loss: 0.0146
# Epoch  16 Batch  180/269 - Train Accuracy: 0.9725, Validation Accuracy: 0.9695, Loss: 0.0161
# Epoch  16 Batch  200/269 - Train Accuracy: 0.9697, Validation Accuracy: 0.9608, Loss: 0.0145
# Epoch  16 Batch  220/269 - Train Accuracy: 0.9608, Validation Accuracy: 0.9599, Loss: 0.0186
# Epoch  16 Batch  240/269 - Train Accuracy: 0.9675, Validation Accuracy: 0.9608, Loss: 0.0189
# Epoch  16 Batch  260/269 - Train Accuracy: 0.9730, Validation Accuracy: 0.9599, Loss: 0.0155
# Epoch  17 Batch   20/269 - Train Accuracy: 0.9697, Validation Accuracy: 0.9502, Loss: 0.0152
# Epoch  17 Batch   40/269 - Train Accuracy: 0.9586, Validation Accuracy: 0.9624, Loss: 0.0218
# Epoch  17 Batch   60/269 - Train Accuracy: 0.9706, Validation Accuracy: 0.9653, Loss: 0.0174
# Epoch  17 Batch   80/269 - Train Accuracy: 0.9652, Validation Accuracy: 0.9658, Loss: 0.0176
# Epoch  17 Batch  100/269 - Train Accuracy: 0.9684, Validation Accuracy: 0.9722, Loss: 0.0176
# Epoch  17 Batch  120/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9676, Loss: 0.0146
# Epoch  17 Batch  140/269 - Train Accuracy: 0.9587, Validation Accuracy: 0.9595, Loss: 0.0216
# Epoch  17 Batch  160/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9712, Loss: 0.0166
# Epoch  17 Batch  180/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9693, Loss: 0.0165
# Epoch  17 Batch  200/269 - Train Accuracy: 0.9742, Validation Accuracy: 0.9645, Loss: 0.0146
# Epoch  17 Batch  220/269 - Train Accuracy: 0.9668, Validation Accuracy: 0.9691, Loss: 0.0176
# Epoch  17 Batch  240/269 - Train Accuracy: 0.9710, Validation Accuracy: 0.9584, Loss: 0.0150
# Epoch  17 Batch  260/269 - Train Accuracy: 0.9763, Validation Accuracy: 0.9659, Loss: 0.0143
# Epoch  18 Batch   20/269 - Train Accuracy: 0.9759, Validation Accuracy: 0.9683, Loss: 0.0155
# Epoch  18 Batch   40/269 - Train Accuracy: 0.9628, Validation Accuracy: 0.9601, Loss: 0.0222
# Epoch  18 Batch   60/269 - Train Accuracy: 0.9761, Validation Accuracy: 0.9708, Loss: 0.0169
# Epoch  18 Batch   80/269 - Train Accuracy: 0.9723, Validation Accuracy: 0.9643, Loss: 0.0152
# Epoch  18 Batch  100/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9638, Loss: 0.0166
# Epoch  18 Batch  120/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9658, Loss: 0.0147
# Epoch  18 Batch  140/269 - Train Accuracy: 0.9716, Validation Accuracy: 0.9674, Loss: 0.0197
# Epoch  18 Batch  160/269 - Train Accuracy: 0.9775, Validation Accuracy: 0.9717, Loss: 0.0161
# Epoch  18 Batch  180/269 - Train Accuracy: 0.9762, Validation Accuracy: 0.9699, Loss: 0.0140
# Epoch  18 Batch  200/269 - Train Accuracy: 0.9695, Validation Accuracy: 0.9502, Loss: 0.0142
# Epoch  18 Batch  220/269 - Train Accuracy: 0.9648, Validation Accuracy: 0.9688, Loss: 0.0162
# Epoch  18 Batch  240/269 - Train Accuracy: 0.9723, Validation Accuracy: 0.9600, Loss: 0.0150
# Epoch  18 Batch  260/269 - Train Accuracy: 0.9783, Validation Accuracy: 0.9700, Loss: 0.0136
# Epoch  19 Batch   20/269 - Train Accuracy: 0.9716, Validation Accuracy: 0.9622, Loss: 0.0165
# Epoch  19 Batch   40/269 - Train Accuracy: 0.9563, Validation Accuracy: 0.9614, Loss: 0.0199
# Epoch  19 Batch   60/269 - Train Accuracy: 0.9732, Validation Accuracy: 0.9661, Loss: 0.0181
# Epoch  19 Batch   80/269 - Train Accuracy: 0.9776, Validation Accuracy: 0.9621, Loss: 0.0141
# Epoch  19 Batch  100/269 - Train Accuracy: 0.9668, Validation Accuracy: 0.9667, Loss: 0.0175
# Epoch  19 Batch  120/269 - Train Accuracy: 0.9698, Validation Accuracy: 0.9646, Loss: 0.0160
# Epoch  19 Batch  140/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9595, Loss: 0.0192
# Epoch  19 Batch  160/269 - Train Accuracy: 0.9769, Validation Accuracy: 0.9716, Loss: 0.0151
# Epoch  19 Batch  180/269 - Train Accuracy: 0.9736, Validation Accuracy: 0.9671, Loss: 0.0209
# Epoch  19 Batch  200/269 - Train Accuracy: 0.9697, Validation Accuracy: 0.9642, Loss: 0.0177
# Epoch  19 Batch  220/269 - Train Accuracy: 0.9588, Validation Accuracy: 0.9587, Loss: 0.0199
# Epoch  19 Batch  240/269 - Train Accuracy: 0.9656, Validation Accuracy: 0.9574, Loss: 0.0175
# Epoch  19 Batch  260/269 - Train Accuracy: 0.9729, Validation Accuracy: 0.9689, Loss: 0.0165
# Epoch  20 Batch   20/269 - Train Accuracy: 0.9748, Validation Accuracy: 0.9651, Loss: 0.0171
# Epoch  20 Batch   40/269 - Train Accuracy: 0.9648, Validation Accuracy: 0.9652, Loss: 0.0178
# Epoch  20 Batch   60/269 - Train Accuracy: 0.9727, Validation Accuracy: 0.9565, Loss: 0.0181
# Epoch  20 Batch   80/269 - Train Accuracy: 0.9834, Validation Accuracy: 0.9727, Loss: 0.0129
# Epoch  20 Batch  100/269 - Train Accuracy: 0.9632, Validation Accuracy: 0.9628, Loss: 0.0152
# Epoch  20 Batch  120/269 - Train Accuracy: 0.9679, Validation Accuracy: 0.9657, Loss: 0.0170
# Epoch  20 Batch  140/269 - Train Accuracy: 0.9665, Validation Accuracy: 0.9711, Loss: 0.0187
# Epoch  20 Batch  160/269 - Train Accuracy: 0.9768, Validation Accuracy: 0.9678, Loss: 0.0140
# Epoch  20 Batch  180/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9714, Loss: 0.0132
# Epoch  20 Batch  200/269 - Train Accuracy: 0.9713, Validation Accuracy: 0.9631, Loss: 0.0122
# Epoch  20 Batch  220/269 - Train Accuracy: 0.9630, Validation Accuracy: 0.9635, Loss: 0.0166
# Epoch  20 Batch  240/269 - Train Accuracy: 0.9723, Validation Accuracy: 0.9724, Loss: 0.0154
# Epoch  20 Batch  260/269 - Train Accuracy: 0.9790, Validation Accuracy: 0.9703, Loss: 0.0126
# Epoch  21 Batch   20/269 - Train Accuracy: 0.9754, Validation Accuracy: 0.9675, Loss: 0.0185
# Epoch  21 Batch   40/269 - Train Accuracy: 0.9639, Validation Accuracy: 0.9702, Loss: 0.0187
# Epoch  21 Batch   60/269 - Train Accuracy: 0.9774, Validation Accuracy: 0.9703, Loss: 0.0167
# Epoch  21 Batch   80/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9754, Loss: 0.0123
# Epoch  21 Batch  100/269 - Train Accuracy: 0.9636, Validation Accuracy: 0.9683, Loss: 0.0149
# Epoch  21 Batch  120/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9651, Loss: 0.0153
# Epoch  21 Batch  140/269 - Train Accuracy: 0.9697, Validation Accuracy: 0.9748, Loss: 0.0182
# Epoch  21 Batch  160/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9744, Loss: 0.0113
# Epoch  21 Batch  180/269 - Train Accuracy: 0.9851, Validation Accuracy: 0.9751, Loss: 0.0120
# Epoch  21 Batch  200/269 - Train Accuracy: 0.9755, Validation Accuracy: 0.9700, Loss: 0.0119
# Epoch  21 Batch  220/269 - Train Accuracy: 0.9678, Validation Accuracy: 0.9623, Loss: 0.0146
# Epoch  21 Batch  240/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9764, Loss: 0.0151
# Epoch  21 Batch  260/269 - Train Accuracy: 0.9811, Validation Accuracy: 0.9700, Loss: 0.0124
# Epoch  22 Batch   20/269 - Train Accuracy: 0.9823, Validation Accuracy: 0.9714, Loss: 0.0140
# Epoch  22 Batch   40/269 - Train Accuracy: 0.9656, Validation Accuracy: 0.9628, Loss: 0.0169
# Epoch  22 Batch   60/269 - Train Accuracy: 0.9771, Validation Accuracy: 0.9712, Loss: 0.0171
# Epoch  22 Batch   80/269 - Train Accuracy: 0.9791, Validation Accuracy: 0.9729, Loss: 0.0123
# Epoch  22 Batch  100/269 - Train Accuracy: 0.9711, Validation Accuracy: 0.9680, Loss: 0.0150
# Epoch  22 Batch  120/269 - Train Accuracy: 0.9693, Validation Accuracy: 0.9624, Loss: 0.0141
# Epoch  22 Batch  140/269 - Train Accuracy: 0.9689, Validation Accuracy: 0.9678, Loss: 0.0201
# Epoch  22 Batch  160/269 - Train Accuracy: 0.9805, Validation Accuracy: 0.9753, Loss: 0.0149
# Epoch  22 Batch  180/269 - Train Accuracy: 0.9804, Validation Accuracy: 0.9744, Loss: 0.0122
# Epoch  22 Batch  200/269 - Train Accuracy: 0.9725, Validation Accuracy: 0.9608, Loss: 0.0137
# Epoch  22 Batch  220/269 - Train Accuracy: 0.9701, Validation Accuracy: 0.9725, Loss: 0.0155
# Epoch  22 Batch  240/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9723, Loss: 0.0135
# Epoch  22 Batch  260/269 - Train Accuracy: 0.9801, Validation Accuracy: 0.9734, Loss: 0.0128
# Epoch  23 Batch   20/269 - Train Accuracy: 0.9829, Validation Accuracy: 0.9650, Loss: 0.0138
# Epoch  23 Batch   40/269 - Train Accuracy: 0.9547, Validation Accuracy: 0.9626, Loss: 0.0199
# Epoch  23 Batch   60/269 - Train Accuracy: 0.9703, Validation Accuracy: 0.9519, Loss: 0.0203
# Epoch  23 Batch   80/269 - Train Accuracy: 0.9801, Validation Accuracy: 0.9652, Loss: 0.0141
# Epoch  23 Batch  100/269 - Train Accuracy: 0.9640, Validation Accuracy: 0.9656, Loss: 0.0185
# Epoch  23 Batch  120/269 - Train Accuracy: 0.9670, Validation Accuracy: 0.9668, Loss: 0.0187
# Epoch  23 Batch  140/269 - Train Accuracy: 0.9722, Validation Accuracy: 0.9613, Loss: 0.0214
# Epoch  23 Batch  160/269 - Train Accuracy: 0.9739, Validation Accuracy: 0.9736, Loss: 0.0150
# Epoch  23 Batch  180/269 - Train Accuracy: 0.9764, Validation Accuracy: 0.9759, Loss: 0.0140
# Epoch  23 Batch  200/269 - Train Accuracy: 0.9796, Validation Accuracy: 0.9741, Loss: 0.0128
# Epoch  23 Batch  220/269 - Train Accuracy: 0.9681, Validation Accuracy: 0.9686, Loss: 0.0131
# Epoch  23 Batch  240/269 - Train Accuracy: 0.9727, Validation Accuracy: 0.9732, Loss: 0.0133
# Epoch  23 Batch  260/269 - Train Accuracy: 0.9831, Validation Accuracy: 0.9692, Loss: 0.0129
# Epoch  24 Batch   20/269 - Train Accuracy: 0.9782, Validation Accuracy: 0.9656, Loss: 0.0138
# Epoch  24 Batch   40/269 - Train Accuracy: 0.9687, Validation Accuracy: 0.9682, Loss: 0.0175
# Epoch  24 Batch   60/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9641, Loss: 0.0184
# Epoch  24 Batch   80/269 - Train Accuracy: 0.9808, Validation Accuracy: 0.9671, Loss: 0.0127
# Epoch  24 Batch  100/269 - Train Accuracy: 0.9727, Validation Accuracy: 0.9643, Loss: 0.0140
# Epoch  24 Batch  120/269 - Train Accuracy: 0.9707, Validation Accuracy: 0.9703, Loss: 0.0142
# Epoch  24 Batch  140/269 - Train Accuracy: 0.9703, Validation Accuracy: 0.9740, Loss: 0.0175
# Epoch  24 Batch  160/269 - Train Accuracy: 0.9782, Validation Accuracy: 0.9664, Loss: 0.0130
# Epoch  24 Batch  180/269 - Train Accuracy: 0.9758, Validation Accuracy: 0.9665, Loss: 0.0143
# Epoch  24 Batch  200/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9727, Loss: 0.0120
# Epoch  24 Batch  220/269 - Train Accuracy: 0.9681, Validation Accuracy: 0.9670, Loss: 0.0158
# Epoch  24 Batch  240/269 - Train Accuracy: 0.9758, Validation Accuracy: 0.9774, Loss: 0.0147
# Epoch  24 Batch  260/269 - Train Accuracy: 0.9793, Validation Accuracy: 0.9720, Loss: 0.0133
# Epoch  25 Batch   20/269 - Train Accuracy: 0.9757, Validation Accuracy: 0.9658, Loss: 0.0159
# Epoch  25 Batch   40/269 - Train Accuracy: 0.9637, Validation Accuracy: 0.9635, Loss: 0.0203
# Epoch  25 Batch   60/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9622, Loss: 0.0175
# Epoch  25 Batch   80/269 - Train Accuracy: 0.9762, Validation Accuracy: 0.9671, Loss: 0.0163
# Epoch  25 Batch  100/269 - Train Accuracy: 0.9733, Validation Accuracy: 0.9670, Loss: 0.0153
# Epoch  25 Batch  120/269 - Train Accuracy: 0.9675, Validation Accuracy: 0.9616, Loss: 0.0145
# Epoch  25 Batch  140/269 - Train Accuracy: 0.9719, Validation Accuracy: 0.9608, Loss: 0.0176
# Epoch  25 Batch  160/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9793, Loss: 0.0133
# Epoch  25 Batch  180/269 - Train Accuracy: 0.9809, Validation Accuracy: 0.9705, Loss: 0.0128
# Epoch  25 Batch  200/269 - Train Accuracy: 0.9791, Validation Accuracy: 0.9713, Loss: 0.0134
# Epoch  25 Batch  220/269 - Train Accuracy: 0.9639, Validation Accuracy: 0.9651, Loss: 0.0161
# Epoch  25 Batch  240/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9616, Loss: 0.0162
# Epoch  25 Batch  260/269 - Train Accuracy: 0.9803, Validation Accuracy: 0.9672, Loss: 0.0137
# Epoch  26 Batch   20/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9695, Loss: 0.0138
# Epoch  26 Batch   40/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9639, Loss: 0.0185
# Epoch  26 Batch   60/269 - Train Accuracy: 0.9698, Validation Accuracy: 0.9609, Loss: 0.0174
# Epoch  26 Batch   80/269 - Train Accuracy: 0.9718, Validation Accuracy: 0.9710, Loss: 0.0168
# Epoch  26 Batch  100/269 - Train Accuracy: 0.9696, Validation Accuracy: 0.9628, Loss: 0.0147
# Epoch  26 Batch  120/269 - Train Accuracy: 0.9625, Validation Accuracy: 0.9662, Loss: 0.0171
# Epoch  26 Batch  140/269 - Train Accuracy: 0.9740, Validation Accuracy: 0.9726, Loss: 0.0179
# Epoch  26 Batch  160/269 - Train Accuracy: 0.9759, Validation Accuracy: 0.9684, Loss: 0.0126
# Epoch  26 Batch  180/269 - Train Accuracy: 0.9779, Validation Accuracy: 0.9688, Loss: 0.0117
# Epoch  26 Batch  200/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9744, Loss: 0.0124
# Epoch  26 Batch  220/269 - Train Accuracy: 0.9665, Validation Accuracy: 0.9674, Loss: 0.0140
# Epoch  26 Batch  240/269 - Train Accuracy: 0.9815, Validation Accuracy: 0.9729, Loss: 0.0123
# Epoch  26 Batch  260/269 - Train Accuracy: 0.9772, Validation Accuracy: 0.9704, Loss: 0.0124
# Epoch  27 Batch   20/269 - Train Accuracy: 0.9764, Validation Accuracy: 0.9668, Loss: 0.0137
# Epoch  27 Batch   40/269 - Train Accuracy: 0.9687, Validation Accuracy: 0.9591, Loss: 0.0162
# Epoch  27 Batch   60/269 - Train Accuracy: 0.9770, Validation Accuracy: 0.9720, Loss: 0.0153
# Epoch  27 Batch   80/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9696, Loss: 0.0104
# Epoch  27 Batch  100/269 - Train Accuracy: 0.9722, Validation Accuracy: 0.9709, Loss: 0.0125
# Epoch  27 Batch  120/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9735, Loss: 0.0138
# Epoch  27 Batch  140/269 - Train Accuracy: 0.9799, Validation Accuracy: 0.9786, Loss: 0.0147
# Epoch  27 Batch  160/269 - Train Accuracy: 0.9810, Validation Accuracy: 0.9732, Loss: 0.0105
# Epoch  27 Batch  180/269 - Train Accuracy: 0.9840, Validation Accuracy: 0.9776, Loss: 0.0096
# Epoch  27 Batch  200/269 - Train Accuracy: 0.9818, Validation Accuracy: 0.9710, Loss: 0.0128
# Epoch  27 Batch  220/269 - Train Accuracy: 0.9703, Validation Accuracy: 0.9743, Loss: 0.0146
# Epoch  27 Batch  240/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9712, Loss: 0.0125
# Epoch  27 Batch  260/269 - Train Accuracy: 0.9798, Validation Accuracy: 0.9711, Loss: 0.0111
# Epoch  28 Batch   20/269 - Train Accuracy: 0.9762, Validation Accuracy: 0.9668, Loss: 0.0126
# Epoch  28 Batch   40/269 - Train Accuracy: 0.9647, Validation Accuracy: 0.9623, Loss: 0.0162
# Epoch  28 Batch   60/269 - Train Accuracy: 0.9790, Validation Accuracy: 0.9670, Loss: 0.0134
# Epoch  28 Batch   80/269 - Train Accuracy: 0.9818, Validation Accuracy: 0.9642, Loss: 0.0127
# Epoch  28 Batch  100/269 - Train Accuracy: 0.9711, Validation Accuracy: 0.9644, Loss: 0.0134
# Epoch  28 Batch  120/269 - Train Accuracy: 0.9693, Validation Accuracy: 0.9654, Loss: 0.0123
# Epoch  28 Batch  140/269 - Train Accuracy: 0.9744, Validation Accuracy: 0.9648, Loss: 0.0160
# Epoch  28 Batch  160/269 - Train Accuracy: 0.9734, Validation Accuracy: 0.9777, Loss: 0.0148
# Epoch  28 Batch  180/269 - Train Accuracy: 0.9807, Validation Accuracy: 0.9692, Loss: 0.0128
# Epoch  28 Batch  200/269 - Train Accuracy: 0.9790, Validation Accuracy: 0.9689, Loss: 0.0119
# Epoch  28 Batch  220/269 - Train Accuracy: 0.9638, Validation Accuracy: 0.9663, Loss: 0.0155
# Epoch  28 Batch  240/269 - Train Accuracy: 0.9784, Validation Accuracy: 0.9767, Loss: 0.0113
# Epoch  28 Batch  260/269 - Train Accuracy: 0.9841, Validation Accuracy: 0.9720, Loss: 0.0121
# Epoch  29 Batch   20/269 - Train Accuracy: 0.9744, Validation Accuracy: 0.9695, Loss: 0.0137
# Epoch  29 Batch   40/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9674, Loss: 0.0158
# Epoch  29 Batch   60/269 - Train Accuracy: 0.9791, Validation Accuracy: 0.9709, Loss: 0.0169
# Epoch  29 Batch   80/269 - Train Accuracy: 0.9794, Validation Accuracy: 0.9660, Loss: 0.0129
# Epoch  29 Batch  100/269 - Train Accuracy: 0.9709, Validation Accuracy: 0.9569, Loss: 0.0121
# Epoch  29 Batch  120/269 - Train Accuracy: 0.9663, Validation Accuracy: 0.9682, Loss: 0.0126
# Epoch  29 Batch  140/269 - Train Accuracy: 0.9732, Validation Accuracy: 0.9765, Loss: 0.0171
# Epoch  29 Batch  160/269 - Train Accuracy: 0.9836, Validation Accuracy: 0.9750, Loss: 0.0110
# Epoch  29 Batch  180/269 - Train Accuracy: 0.9833, Validation Accuracy: 0.9683, Loss: 0.0122
# Epoch  29 Batch  200/269 - Train Accuracy: 0.9764, Validation Accuracy: 0.9669, Loss: 0.0135
# Epoch  29 Batch  220/269 - Train Accuracy: 0.9695, Validation Accuracy: 0.9658, Loss: 0.0175
# Epoch  29 Batch  240/269 - Train Accuracy: 0.9719, Validation Accuracy: 0.9692, Loss: 0.0142
# Epoch  29 Batch  260/269 - Train Accuracy: 0.9840, Validation Accuracy: 0.9640, Loss: 0.0148
# Epoch  30 Batch   20/269 - Train Accuracy: 0.9736, Validation Accuracy: 0.9616, Loss: 0.0174
# Epoch  30 Batch   40/269 - Train Accuracy: 0.9675, Validation Accuracy: 0.9672, Loss: 0.0171
# Epoch  30 Batch   60/269 - Train Accuracy: 0.9748, Validation Accuracy: 0.9737, Loss: 0.0156
# Epoch  30 Batch   80/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9689, Loss: 0.0145
# Epoch  30 Batch  100/269 - Train Accuracy: 0.9746, Validation Accuracy: 0.9640, Loss: 0.0109
# Epoch  30 Batch  120/269 - Train Accuracy: 0.9629, Validation Accuracy: 0.9734, Loss: 0.0148
# Epoch  30 Batch  140/269 - Train Accuracy: 0.9788, Validation Accuracy: 0.9719, Loss: 0.0165
# Epoch  30 Batch  160/269 - Train Accuracy: 0.9838, Validation Accuracy: 0.9762, Loss: 0.0108
# Epoch  30 Batch  180/269 - Train Accuracy: 0.9824, Validation Accuracy: 0.9691, Loss: 0.0117
# Epoch  30 Batch  200/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9668, Loss: 0.0122
# Epoch  30 Batch  220/269 - Train Accuracy: 0.9637, Validation Accuracy: 0.9619, Loss: 0.0166
# Epoch  30 Batch  240/269 - Train Accuracy: 0.9712, Validation Accuracy: 0.9703, Loss: 0.0143
# Epoch  30 Batch  260/269 - Train Accuracy: 0.9753, Validation Accuracy: 0.9662, Loss: 0.0120
# Epoch  31 Batch   20/269 - Train Accuracy: 0.9783, Validation Accuracy: 0.9681, Loss: 0.0164
# Epoch  31 Batch   40/269 - Train Accuracy: 0.9701, Validation Accuracy: 0.9593, Loss: 0.0153
# Epoch  31 Batch   60/269 - Train Accuracy: 0.9724, Validation Accuracy: 0.9743, Loss: 0.0162
# Epoch  31 Batch   80/269 - Train Accuracy: 0.9760, Validation Accuracy: 0.9680, Loss: 0.0114
# Epoch  31 Batch  100/269 - Train Accuracy: 0.9734, Validation Accuracy: 0.9646, Loss: 0.0132
# Epoch  31 Batch  120/269 - Train Accuracy: 0.9701, Validation Accuracy: 0.9735, Loss: 0.0124
# Epoch  31 Batch  140/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9806, Loss: 0.0152
# Epoch  31 Batch  160/269 - Train Accuracy: 0.9812, Validation Accuracy: 0.9716, Loss: 0.0108
# Epoch  31 Batch  180/269 - Train Accuracy: 0.9837, Validation Accuracy: 0.9779, Loss: 0.0108
# Epoch  31 Batch  200/269 - Train Accuracy: 0.9895, Validation Accuracy: 0.9710, Loss: 0.0093
# Epoch  31 Batch  220/269 - Train Accuracy: 0.9730, Validation Accuracy: 0.9740, Loss: 0.0126
# Epoch  31 Batch  240/269 - Train Accuracy: 0.9755, Validation Accuracy: 0.9800, Loss: 0.0120
# Epoch  31 Batch  260/269 - Train Accuracy: 0.9810, Validation Accuracy: 0.9732, Loss: 0.0115
# Epoch  32 Batch   20/269 - Train Accuracy: 0.9811, Validation Accuracy: 0.9643, Loss: 0.0126
# Epoch  32 Batch   40/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9705, Loss: 0.0135
# Epoch  32 Batch   60/269 - Train Accuracy: 0.9795, Validation Accuracy: 0.9695, Loss: 0.0133
# Epoch  32 Batch   80/269 - Train Accuracy: 0.9824, Validation Accuracy: 0.9715, Loss: 0.0111
# Epoch  32 Batch  100/269 - Train Accuracy: 0.9778, Validation Accuracy: 0.9661, Loss: 0.0128
# Epoch  32 Batch  120/269 - Train Accuracy: 0.9733, Validation Accuracy: 0.9681, Loss: 0.0121
# Epoch  32 Batch  140/269 - Train Accuracy: 0.9754, Validation Accuracy: 0.9716, Loss: 0.0172
# Epoch  32 Batch  160/269 - Train Accuracy: 0.9856, Validation Accuracy: 0.9769, Loss: 0.0102
# Epoch  32 Batch  180/269 - Train Accuracy: 0.9777, Validation Accuracy: 0.9721, Loss: 0.0101
# Epoch  32 Batch  200/269 - Train Accuracy: 0.9849, Validation Accuracy: 0.9688, Loss: 0.0131
# Epoch  32 Batch  220/269 - Train Accuracy: 0.9740, Validation Accuracy: 0.9704, Loss: 0.0139
# Epoch  32 Batch  240/269 - Train Accuracy: 0.9778, Validation Accuracy: 0.9790, Loss: 0.0110
# Epoch  32 Batch  260/269 - Train Accuracy: 0.9863, Validation Accuracy: 0.9628, Loss: 0.0099
# Epoch  33 Batch   20/269 - Train Accuracy: 0.9833, Validation Accuracy: 0.9646, Loss: 0.0130
# Epoch  33 Batch   40/269 - Train Accuracy: 0.9742, Validation Accuracy: 0.9648, Loss: 0.0177
# Epoch  33 Batch   60/269 - Train Accuracy: 0.9644, Validation Accuracy: 0.9599, Loss: 0.0252
# Epoch  33 Batch   80/269 - Train Accuracy: 0.9782, Validation Accuracy: 0.9616, Loss: 0.0153
# Epoch  33 Batch  100/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9606, Loss: 0.0170
# Epoch  33 Batch  120/269 - Train Accuracy: 0.9718, Validation Accuracy: 0.9688, Loss: 0.0141
# Epoch  33 Batch  140/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9735, Loss: 0.0185
# Epoch  33 Batch  160/269 - Train Accuracy: 0.9796, Validation Accuracy: 0.9757, Loss: 0.0118
# Epoch  33 Batch  180/269 - Train Accuracy: 0.9804, Validation Accuracy: 0.9676, Loss: 0.0114
# Epoch  33 Batch  200/269 - Train Accuracy: 0.9841, Validation Accuracy: 0.9682, Loss: 0.0105
# Epoch  33 Batch  220/269 - Train Accuracy: 0.9721, Validation Accuracy: 0.9628, Loss: 0.0157
# Epoch  33 Batch  240/269 - Train Accuracy: 0.9783, Validation Accuracy: 0.9749, Loss: 0.0124
# Epoch  33 Batch  260/269 - Train Accuracy: 0.9797, Validation Accuracy: 0.9724, Loss: 0.0114
# Epoch  34 Batch   20/269 - Train Accuracy: 0.9752, Validation Accuracy: 0.9593, Loss: 0.0123
# Epoch  34 Batch   40/269 - Train Accuracy: 0.9748, Validation Accuracy: 0.9642, Loss: 0.0135
# Epoch  34 Batch   60/269 - Train Accuracy: 0.9748, Validation Accuracy: 0.9708, Loss: 0.0149
# Epoch  34 Batch   80/269 - Train Accuracy: 0.9776, Validation Accuracy: 0.9657, Loss: 0.0112
# Epoch  34 Batch  100/269 - Train Accuracy: 0.9720, Validation Accuracy: 0.9660, Loss: 0.0127
# Epoch  34 Batch  120/269 - Train Accuracy: 0.9666, Validation Accuracy: 0.9720, Loss: 0.0134
# Epoch  34 Batch  140/269 - Train Accuracy: 0.9750, Validation Accuracy: 0.9722, Loss: 0.0131
# Epoch  34 Batch  160/269 - Train Accuracy: 0.9768, Validation Accuracy: 0.9728, Loss: 0.0113
# Epoch  34 Batch  180/269 - Train Accuracy: 0.9815, Validation Accuracy: 0.9716, Loss: 0.0104
# Epoch  34 Batch  200/269 - Train Accuracy: 0.9848, Validation Accuracy: 0.9660, Loss: 0.0097
# Epoch  34 Batch  220/269 - Train Accuracy: 0.9740, Validation Accuracy: 0.9669, Loss: 0.0113
# Epoch  34 Batch  240/269 - Train Accuracy: 0.9740, Validation Accuracy: 0.9720, Loss: 0.0125
# Epoch  34 Batch  260/269 - Train Accuracy: 0.9822, Validation Accuracy: 0.9798, Loss: 0.0126
# Epoch  35 Batch   20/269 - Train Accuracy: 0.9803, Validation Accuracy: 0.9678, Loss: 0.0126
# Epoch  35 Batch   40/269 - Train Accuracy: 0.9702, Validation Accuracy: 0.9671, Loss: 0.0147
# Epoch  35 Batch   60/269 - Train Accuracy: 0.9766, Validation Accuracy: 0.9679, Loss: 0.0146
# Epoch  35 Batch   80/269 - Train Accuracy: 0.9868, Validation Accuracy: 0.9741, Loss: 0.0108
# Epoch  35 Batch  100/269 - Train Accuracy: 0.9742, Validation Accuracy: 0.9680, Loss: 0.0104
# Epoch  35 Batch  120/269 - Train Accuracy: 0.9699, Validation Accuracy: 0.9701, Loss: 0.0135
# Epoch  35 Batch  140/269 - Train Accuracy: 0.9771, Validation Accuracy: 0.9689, Loss: 0.0164
# Epoch  35 Batch  160/269 - Train Accuracy: 0.9813, Validation Accuracy: 0.9742, Loss: 0.0102
# Epoch  35 Batch  180/269 - Train Accuracy: 0.9790, Validation Accuracy: 0.9669, Loss: 0.0103
# Epoch  35 Batch  200/269 - Train Accuracy: 0.9844, Validation Accuracy: 0.9671, Loss: 0.0098
# Epoch  35 Batch  220/269 - Train Accuracy: 0.9786, Validation Accuracy: 0.9719, Loss: 0.0113
# Epoch  35 Batch  240/269 - Train Accuracy: 0.9762, Validation Accuracy: 0.9758, Loss: 0.0118
# Epoch  35 Batch  260/269 - Train Accuracy: 0.9841, Validation Accuracy: 0.9716, Loss: 0.0100
# Epoch  36 Batch   20/269 - Train Accuracy: 0.9730, Validation Accuracy: 0.9664, Loss: 0.0120
# Epoch  36 Batch   40/269 - Train Accuracy: 0.9725, Validation Accuracy: 0.9685, Loss: 0.0165
# Epoch  36 Batch   60/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9647, Loss: 0.0138
# Epoch  36 Batch   80/269 - Train Accuracy: 0.9795, Validation Accuracy: 0.9664, Loss: 0.0113
# Epoch  36 Batch  100/269 - Train Accuracy: 0.9803, Validation Accuracy: 0.9644, Loss: 0.0115
# Epoch  36 Batch  120/269 - Train Accuracy: 0.9699, Validation Accuracy: 0.9645, Loss: 0.0132
# Epoch  36 Batch  140/269 - Train Accuracy: 0.9718, Validation Accuracy: 0.9723, Loss: 0.0173
# Epoch  36 Batch  160/269 - Train Accuracy: 0.9823, Validation Accuracy: 0.9765, Loss: 0.0130
# Epoch  36 Batch  180/269 - Train Accuracy: 0.9774, Validation Accuracy: 0.9708, Loss: 0.0155
# Epoch  36 Batch  200/269 - Train Accuracy: 0.9835, Validation Accuracy: 0.9665, Loss: 0.0106
# Epoch  36 Batch  220/269 - Train Accuracy: 0.9761, Validation Accuracy: 0.9646, Loss: 0.0134
# Epoch  36 Batch  240/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9720, Loss: 0.0119
# Epoch  36 Batch  260/269 - Train Accuracy: 0.9822, Validation Accuracy: 0.9776, Loss: 0.0115
# Epoch  37 Batch   20/269 - Train Accuracy: 0.9784, Validation Accuracy: 0.9593, Loss: 0.0115
# Epoch  37 Batch   40/269 - Train Accuracy: 0.9736, Validation Accuracy: 0.9704, Loss: 0.0131
# Epoch  37 Batch   60/269 - Train Accuracy: 0.9735, Validation Accuracy: 0.9702, Loss: 0.0156
# Epoch  37 Batch   80/269 - Train Accuracy: 0.9854, Validation Accuracy: 0.9710, Loss: 0.0126
# Epoch  37 Batch  100/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9711, Loss: 0.0114
# Epoch  37 Batch  120/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9693, Loss: 0.0138
# Epoch  37 Batch  140/269 - Train Accuracy: 0.9754, Validation Accuracy: 0.9767, Loss: 0.0171
# Epoch  37 Batch  160/269 - Train Accuracy: 0.9855, Validation Accuracy: 0.9724, Loss: 0.0115
# Epoch  37 Batch  180/269 - Train Accuracy: 0.9826, Validation Accuracy: 0.9689, Loss: 0.0115
# Epoch  37 Batch  200/269 - Train Accuracy: 0.9845, Validation Accuracy: 0.9735, Loss: 0.0093
# Epoch  37 Batch  220/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9736, Loss: 0.0128
# Epoch  37 Batch  240/269 - Train Accuracy: 0.9756, Validation Accuracy: 0.9703, Loss: 0.0124
# Epoch  37 Batch  260/269 - Train Accuracy: 0.9823, Validation Accuracy: 0.9746, Loss: 0.0121
# Epoch  38 Batch   20/269 - Train Accuracy: 0.9840, Validation Accuracy: 0.9708, Loss: 0.0096
# Epoch  38 Batch   40/269 - Train Accuracy: 0.9765, Validation Accuracy: 0.9727, Loss: 0.0143
# Epoch  38 Batch   60/269 - Train Accuracy: 0.9664, Validation Accuracy: 0.9661, Loss: 0.0157
# Epoch  38 Batch   80/269 - Train Accuracy: 0.9816, Validation Accuracy: 0.9704, Loss: 0.0151
# Epoch  38 Batch  100/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9698, Loss: 0.0122
# Epoch  38 Batch  120/269 - Train Accuracy: 0.9719, Validation Accuracy: 0.9707, Loss: 0.0151
# Epoch  38 Batch  140/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9759, Loss: 0.0165
# Epoch  38 Batch  160/269 - Train Accuracy: 0.9882, Validation Accuracy: 0.9734, Loss: 0.0093
# Epoch  38 Batch  180/269 - Train Accuracy: 0.9843, Validation Accuracy: 0.9753, Loss: 0.0105
# Epoch  38 Batch  200/269 - Train Accuracy: 0.9835, Validation Accuracy: 0.9751, Loss: 0.0097
# Epoch  38 Batch  220/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9785, Loss: 0.0115
# Epoch  38 Batch  240/269 - Train Accuracy: 0.9808, Validation Accuracy: 0.9736, Loss: 0.0106
# Epoch  38 Batch  260/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9802, Loss: 0.0092
# Epoch  39 Batch   20/269 - Train Accuracy: 0.9750, Validation Accuracy: 0.9699, Loss: 0.0110
# Epoch  39 Batch   40/269 - Train Accuracy: 0.9679, Validation Accuracy: 0.9704, Loss: 0.0123
# Epoch  39 Batch   60/269 - Train Accuracy: 0.9757, Validation Accuracy: 0.9685, Loss: 0.0125
# Epoch  39 Batch   80/269 - Train Accuracy: 0.9793, Validation Accuracy: 0.9745, Loss: 0.0110
# Epoch  39 Batch  100/269 - Train Accuracy: 0.9724, Validation Accuracy: 0.9785, Loss: 0.0126
# Epoch  39 Batch  120/269 - Train Accuracy: 0.9677, Validation Accuracy: 0.9728, Loss: 0.0129
# Epoch  39 Batch  140/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9750, Loss: 0.0137
# Epoch  39 Batch  160/269 - Train Accuracy: 0.9845, Validation Accuracy: 0.9819, Loss: 0.0087
# Epoch  39 Batch  180/269 - Train Accuracy: 0.9841, Validation Accuracy: 0.9695, Loss: 0.0108
# Epoch  39 Batch  200/269 - Train Accuracy: 0.9818, Validation Accuracy: 0.9741, Loss: 0.0095
# Epoch  39 Batch  220/269 - Train Accuracy: 0.9762, Validation Accuracy: 0.9689, Loss: 0.0121
# Epoch  39 Batch  240/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9682, Loss: 0.0114
# Epoch  39 Batch  260/269 - Train Accuracy: 0.9832, Validation Accuracy: 0.9780, Loss: 0.0108
# Epoch  40 Batch   20/269 - Train Accuracy: 0.9838, Validation Accuracy: 0.9714, Loss: 0.0091
# Epoch  40 Batch   40/269 - Train Accuracy: 0.9756, Validation Accuracy: 0.9641, Loss: 0.0113
# Epoch  40 Batch   60/269 - Train Accuracy: 0.9735, Validation Accuracy: 0.9694, Loss: 0.0146
# Epoch  40 Batch   80/269 - Train Accuracy: 0.9774, Validation Accuracy: 0.9748, Loss: 0.0106
# Epoch  40 Batch  100/269 - Train Accuracy: 0.9831, Validation Accuracy: 0.9721, Loss: 0.0097
# Epoch  40 Batch  120/269 - Train Accuracy: 0.9764, Validation Accuracy: 0.9754, Loss: 0.0121
# Epoch  40 Batch  140/269 - Train Accuracy: 0.9789, Validation Accuracy: 0.9770, Loss: 0.0131
# Epoch  40 Batch  160/269 - Train Accuracy: 0.9831, Validation Accuracy: 0.9763, Loss: 0.0096
# Epoch  40 Batch  180/269 - Train Accuracy: 0.9816, Validation Accuracy: 0.9680, Loss: 0.0098
# Epoch  40 Batch  200/269 - Train Accuracy: 0.9860, Validation Accuracy: 0.9707, Loss: 0.0087
# Epoch  40 Batch  220/269 - Train Accuracy: 0.9750, Validation Accuracy: 0.9707, Loss: 0.0115
# Epoch  40 Batch  240/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9754, Loss: 0.0102
# Epoch  40 Batch  260/269 - Train Accuracy: 0.9841, Validation Accuracy: 0.9702, Loss: 0.0092
# Epoch  41 Batch   20/269 - Train Accuracy: 0.9805, Validation Accuracy: 0.9663, Loss: 0.0112
# Epoch  41 Batch   40/269 - Train Accuracy: 0.9851, Validation Accuracy: 0.9730, Loss: 0.0110
# Epoch  41 Batch   60/269 - Train Accuracy: 0.9703, Validation Accuracy: 0.9680, Loss: 0.0145
# Epoch  41 Batch   80/269 - Train Accuracy: 0.9773, Validation Accuracy: 0.9688, Loss: 0.0118
# Epoch  41 Batch  100/269 - Train Accuracy: 0.9799, Validation Accuracy: 0.9683, Loss: 0.0118
# Epoch  41 Batch  120/269 - Train Accuracy: 0.9763, Validation Accuracy: 0.9759, Loss: 0.0121
# Epoch  41 Batch  140/269 - Train Accuracy: 0.9770, Validation Accuracy: 0.9753, Loss: 0.0138
# Epoch  41 Batch  160/269 - Train Accuracy: 0.9829, Validation Accuracy: 0.9707, Loss: 0.0093
# Epoch  41 Batch  180/269 - Train Accuracy: 0.9823, Validation Accuracy: 0.9736, Loss: 0.0101
# Epoch  41 Batch  200/269 - Train Accuracy: 0.9851, Validation Accuracy: 0.9697, Loss: 0.0102
# Epoch  41 Batch  220/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9670, Loss: 0.0120
# Epoch  41 Batch  240/269 - Train Accuracy: 0.9715, Validation Accuracy: 0.9718, Loss: 0.0140
# Epoch  41 Batch  260/269 - Train Accuracy: 0.9874, Validation Accuracy: 0.9714, Loss: 0.0087
# Epoch  42 Batch   20/269 - Train Accuracy: 0.9898, Validation Accuracy: 0.9765, Loss: 0.0105
# Epoch  42 Batch   40/269 - Train Accuracy: 0.9792, Validation Accuracy: 0.9800, Loss: 0.0128
# Epoch  42 Batch   60/269 - Train Accuracy: 0.9757, Validation Accuracy: 0.9793, Loss: 0.0127
# Epoch  42 Batch   80/269 - Train Accuracy: 0.9817, Validation Accuracy: 0.9655, Loss: 0.0089
# Epoch  42 Batch  100/269 - Train Accuracy: 0.9824, Validation Accuracy: 0.9665, Loss: 0.0103
# Epoch  42 Batch  120/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9697, Loss: 0.0112
# Epoch  42 Batch  140/269 - Train Accuracy: 0.9775, Validation Accuracy: 0.9698, Loss: 0.0145
# Epoch  42 Batch  160/269 - Train Accuracy: 0.9845, Validation Accuracy: 0.9782, Loss: 0.0112
# Epoch  42 Batch  180/269 - Train Accuracy: 0.9801, Validation Accuracy: 0.9718, Loss: 0.0106
# Epoch  42 Batch  200/269 - Train Accuracy: 0.9846, Validation Accuracy: 0.9683, Loss: 0.0089
# Epoch  42 Batch  220/269 - Train Accuracy: 0.9716, Validation Accuracy: 0.9724, Loss: 0.0122
# Epoch  42 Batch  240/269 - Train Accuracy: 0.9758, Validation Accuracy: 0.9757, Loss: 0.0131
# Epoch  42 Batch  260/269 - Train Accuracy: 0.9816, Validation Accuracy: 0.9798, Loss: 0.0114
# Epoch  43 Batch   20/269 - Train Accuracy: 0.9819, Validation Accuracy: 0.9691, Loss: 0.0116
# Epoch  43 Batch   40/269 - Train Accuracy: 0.9785, Validation Accuracy: 0.9630, Loss: 0.0131
# Epoch  43 Batch   60/269 - Train Accuracy: 0.9751, Validation Accuracy: 0.9730, Loss: 0.0132
# Epoch  43 Batch   80/269 - Train Accuracy: 0.9839, Validation Accuracy: 0.9736, Loss: 0.0123
# Epoch  43 Batch  100/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9672, Loss: 0.0121
# Epoch  43 Batch  120/269 - Train Accuracy: 0.9763, Validation Accuracy: 0.9743, Loss: 0.0142
# Epoch  43 Batch  140/269 - Train Accuracy: 0.9679, Validation Accuracy: 0.9681, Loss: 0.0186
# Epoch  43 Batch  160/269 - Train Accuracy: 0.9851, Validation Accuracy: 0.9814, Loss: 0.0131
# Epoch  43 Batch  180/269 - Train Accuracy: 0.9796, Validation Accuracy: 0.9634, Loss: 0.0121
# Epoch  43 Batch  200/269 - Train Accuracy: 0.9856, Validation Accuracy: 0.9715, Loss: 0.0117
# Epoch  43 Batch  220/269 - Train Accuracy: 0.9695, Validation Accuracy: 0.9691, Loss: 0.0145
# Epoch  43 Batch  240/269 - Train Accuracy: 0.9812, Validation Accuracy: 0.9713, Loss: 0.0137
# Epoch  43 Batch  260/269 - Train Accuracy: 0.9816, Validation Accuracy: 0.9654, Loss: 0.0110
# Epoch  44 Batch   20/269 - Train Accuracy: 0.9835, Validation Accuracy: 0.9664, Loss: 0.0129
# Epoch  44 Batch   40/269 - Train Accuracy: 0.9700, Validation Accuracy: 0.9658, Loss: 0.0138
# Epoch  44 Batch   60/269 - Train Accuracy: 0.9768, Validation Accuracy: 0.9801, Loss: 0.0117
# Epoch  44 Batch   80/269 - Train Accuracy: 0.9794, Validation Accuracy: 0.9696, Loss: 0.0124
# Epoch  44 Batch  100/269 - Train Accuracy: 0.9765, Validation Accuracy: 0.9746, Loss: 0.0129
# Epoch  44 Batch  120/269 - Train Accuracy: 0.9777, Validation Accuracy: 0.9764, Loss: 0.0144
# Epoch  44 Batch  140/269 - Train Accuracy: 0.9706, Validation Accuracy: 0.9784, Loss: 0.0155
# Epoch  44 Batch  160/269 - Train Accuracy: 0.9840, Validation Accuracy: 0.9769, Loss: 0.0085
# Epoch  44 Batch  180/269 - Train Accuracy: 0.9859, Validation Accuracy: 0.9688, Loss: 0.0081
# Epoch  44 Batch  200/269 - Train Accuracy: 0.9870, Validation Accuracy: 0.9762, Loss: 0.0106
# Epoch  44 Batch  220/269 - Train Accuracy: 0.9774, Validation Accuracy: 0.9640, Loss: 0.0118
# Epoch  44 Batch  240/269 - Train Accuracy: 0.9796, Validation Accuracy: 0.9721, Loss: 0.0125
# Epoch  44 Batch  260/269 - Train Accuracy: 0.9885, Validation Accuracy: 0.9781, Loss: 0.0092
# Epoch  45 Batch   20/269 - Train Accuracy: 0.9757, Validation Accuracy: 0.9646, Loss: 0.0141
# Epoch  45 Batch   40/269 - Train Accuracy: 0.9782, Validation Accuracy: 0.9690, Loss: 0.0124
# Epoch  45 Batch   60/269 - Train Accuracy: 0.9731, Validation Accuracy: 0.9679, Loss: 0.0153
# Epoch  45 Batch   80/269 - Train Accuracy: 0.9828, Validation Accuracy: 0.9652, Loss: 0.0116
# Epoch  45 Batch  100/269 - Train Accuracy: 0.9842, Validation Accuracy: 0.9680, Loss: 0.0118
# Epoch  45 Batch  120/269 - Train Accuracy: 0.9728, Validation Accuracy: 0.9706, Loss: 0.0132
# Epoch  45 Batch  140/269 - Train Accuracy: 0.9761, Validation Accuracy: 0.9764, Loss: 0.0143
# Epoch  45 Batch  160/269 - Train Accuracy: 0.9865, Validation Accuracy: 0.9806, Loss: 0.0101
# Epoch  45 Batch  180/269 - Train Accuracy: 0.9787, Validation Accuracy: 0.9651, Loss: 0.0094
# Epoch  45 Batch  200/269 - Train Accuracy: 0.9847, Validation Accuracy: 0.9613, Loss: 0.0111
# Epoch  45 Batch  220/269 - Train Accuracy: 0.9751, Validation Accuracy: 0.9765, Loss: 0.0121
# Epoch  45 Batch  240/269 - Train Accuracy: 0.9788, Validation Accuracy: 0.9727, Loss: 0.0124
# Epoch  45 Batch  260/269 - Train Accuracy: 0.9888, Validation Accuracy: 0.9711, Loss: 0.0099
# Epoch  46 Batch   20/269 - Train Accuracy: 0.9840, Validation Accuracy: 0.9717, Loss: 0.0100
# Epoch  46 Batch   40/269 - Train Accuracy: 0.9842, Validation Accuracy: 0.9715, Loss: 0.0112
# Epoch  46 Batch   60/269 - Train Accuracy: 0.9759, Validation Accuracy: 0.9655, Loss: 0.0131
# Epoch  46 Batch   80/269 - Train Accuracy: 0.9775, Validation Accuracy: 0.9735, Loss: 0.0127
# Epoch  46 Batch  100/269 - Train Accuracy: 0.9785, Validation Accuracy: 0.9722, Loss: 0.0139
# Epoch  46 Batch  120/269 - Train Accuracy: 0.9760, Validation Accuracy: 0.9711, Loss: 0.0136
# Epoch  46 Batch  140/269 - Train Accuracy: 0.9733, Validation Accuracy: 0.9618, Loss: 0.0146
# Epoch  46 Batch  160/269 - Train Accuracy: 0.9829, Validation Accuracy: 0.9638, Loss: 0.0129
# Epoch  46 Batch  180/269 - Train Accuracy: 0.9826, Validation Accuracy: 0.9676, Loss: 0.0093
# Epoch  46 Batch  200/269 - Train Accuracy: 0.9864, Validation Accuracy: 0.9697, Loss: 0.0088
# Epoch  46 Batch  220/269 - Train Accuracy: 0.9764, Validation Accuracy: 0.9711, Loss: 0.0106
# Epoch  46 Batch  240/269 - Train Accuracy: 0.9778, Validation Accuracy: 0.9688, Loss: 0.0117
# Epoch  46 Batch  260/269 - Train Accuracy: 0.9865, Validation Accuracy: 0.9720, Loss: 0.0081
# Epoch  47 Batch   20/269 - Train Accuracy: 0.9802, Validation Accuracy: 0.9674, Loss: 0.0112
# Epoch  47 Batch   40/269 - Train Accuracy: 0.9729, Validation Accuracy: 0.9735, Loss: 0.0140
# Epoch  47 Batch   60/269 - Train Accuracy: 0.9772, Validation Accuracy: 0.9760, Loss: 0.0113
# Epoch  47 Batch   80/269 - Train Accuracy: 0.9809, Validation Accuracy: 0.9699, Loss: 0.0103
# Epoch  47 Batch  100/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9717, Loss: 0.0103
# Epoch  47 Batch  120/269 - Train Accuracy: 0.9709, Validation Accuracy: 0.9698, Loss: 0.0134
# Epoch  47 Batch  140/269 - Train Accuracy: 0.9796, Validation Accuracy: 0.9743, Loss: 0.0145
# Epoch  47 Batch  160/269 - Train Accuracy: 0.9805, Validation Accuracy: 0.9838, Loss: 0.0116
# Epoch  47 Batch  180/269 - Train Accuracy: 0.9882, Validation Accuracy: 0.9716, Loss: 0.0100
# Epoch  47 Batch  200/269 - Train Accuracy: 0.9872, Validation Accuracy: 0.9665, Loss: 0.0094
# Epoch  47 Batch  220/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9788, Loss: 0.0117
# Epoch  47 Batch  240/269 - Train Accuracy: 0.9811, Validation Accuracy: 0.9746, Loss: 0.0115
# Epoch  47 Batch  260/269 - Train Accuracy: 0.9834, Validation Accuracy: 0.9731, Loss: 0.0117
# Epoch  48 Batch   20/269 - Train Accuracy: 0.9839, Validation Accuracy: 0.9699, Loss: 0.0121
# Epoch  48 Batch   40/269 - Train Accuracy: 0.9742, Validation Accuracy: 0.9706, Loss: 0.0106
# Epoch  48 Batch   60/269 - Train Accuracy: 0.9732, Validation Accuracy: 0.9688, Loss: 0.0124
# Epoch  48 Batch   80/269 - Train Accuracy: 0.9821, Validation Accuracy: 0.9729, Loss: 0.0116
# Epoch  48 Batch  100/269 - Train Accuracy: 0.9768, Validation Accuracy: 0.9806, Loss: 0.0124
# Epoch  48 Batch  120/269 - Train Accuracy: 0.9752, Validation Accuracy: 0.9730, Loss: 0.0112
# Epoch  48 Batch  140/269 - Train Accuracy: 0.9805, Validation Accuracy: 0.9682, Loss: 0.0143
# Epoch  48 Batch  160/269 - Train Accuracy: 0.9843, Validation Accuracy: 0.9691, Loss: 0.0098
# Epoch  48 Batch  180/269 - Train Accuracy: 0.9849, Validation Accuracy: 0.9741, Loss: 0.0081
# Epoch  48 Batch  200/269 - Train Accuracy: 0.9821, Validation Accuracy: 0.9673, Loss: 0.0091
# Epoch  48 Batch  220/269 - Train Accuracy: 0.9788, Validation Accuracy: 0.9790, Loss: 0.0093
# Epoch  48 Batch  240/269 - Train Accuracy: 0.9835, Validation Accuracy: 0.9752, Loss: 0.0101
# Epoch  48 Batch  260/269 - Train Accuracy: 0.9885, Validation Accuracy: 0.9744, Loss: 0.0095
# Epoch  49 Batch   20/269 - Train Accuracy: 0.9833, Validation Accuracy: 0.9744, Loss: 0.0111
# Epoch  49 Batch   40/269 - Train Accuracy: 0.9786, Validation Accuracy: 0.9762, Loss: 0.0123
# Epoch  49 Batch   60/269 - Train Accuracy: 0.9767, Validation Accuracy: 0.9838, Loss: 0.0113
# Epoch  49 Batch   80/269 - Train Accuracy: 0.9848, Validation Accuracy: 0.9700, Loss: 0.0113
# Epoch  49 Batch  100/269 - Train Accuracy: 0.9830, Validation Accuracy: 0.9814, Loss: 0.0098
# Epoch  49 Batch  120/269 - Train Accuracy: 0.9761, Validation Accuracy: 0.9734, Loss: 0.0105
# Epoch  49 Batch  140/269 - Train Accuracy: 0.9735, Validation Accuracy: 0.9750, Loss: 0.0138
# Epoch  49 Batch  160/269 - Train Accuracy: 0.9874, Validation Accuracy: 0.9750, Loss: 0.0079
# Epoch  49 Batch  180/269 - Train Accuracy: 0.9778, Validation Accuracy: 0.9679, Loss: 0.0097
# Epoch  49 Batch  200/269 - Train Accuracy: 0.9887, Validation Accuracy: 0.9728, Loss: 0.0080
# Epoch  49 Batch  220/269 - Train Accuracy: 0.9776, Validation Accuracy: 0.9747, Loss: 0.0116
# Epoch  49 Batch  240/269 - Train Accuracy: 0.9783, Validation Accuracy: 0.9732, Loss: 0.0129
# Epoch  49 Batch  260/269 - Train Accuracy: 0.9804, Validation Accuracy: 0.9755, Loss: 0.0096
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.split(' ')]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [45, 39, 185, 34, 52, 117, 33]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [61, 93, 248, 21, 223, 255, 149, 103, 1]
#   French Words: il a vu un petit camion bleu . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
